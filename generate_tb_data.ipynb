# %%
import os
import copy
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import h5py
from sklearn.preprocessing import StandardScaler
from scipy.optimize import least_squares

np.random.seed(0)

# %%
np.log2(500*700)
# Out:
# 18.416995396494414

# %% [markdown]
# Globals

# %%
IN_ROWS = 100
IN_COLS = 160
OUT_ROWS = 48
OUT_COLS = 48
IMG_COL_BITWIDTH = int(np.ceil(np.log2(IN_COLS+1))+1)
IMG_ROW_BITWIDTH = int(np.ceil(np.log2(IN_ROWS+1))+1)
NUM_CROPS = 1

TESTBENCH_TYPE = "VALUE_EQUALS_INDEX"
assert(TESTBENCH_TYPE in ["VALUE_EQUALS_INDEX"]) # ["REAL_DATA", "VALUE_EQUALS_INDEX", "RANDOM"])
if TESTBENCH_TYPE=="VALUE_EQUALS_INDEX":
    FP_FRAC = 0 # We just want integer values corresponding to the index of each pixel
    FP_INT = 15 # int(np.log2(IN_ROWS*IN_COLS)) + 1 
    FP_TOTAL = FP_FRAC + FP_INT + 1 # We'll keep it signed for simplicity
    DATA_STRING_INSERT = "_INDEX"
    VMAX = IN_ROWS*IN_COLS
elif TESTBENCH_TYPE=="REAL_DATA":
    FP_FRAC = 13
    FP_INT = 2
    FP_TOTAL = FP_FRAC + FP_INT + 1
    DATA_STRING_INSERT = ""
    VMAX = 1
elif TESTBENCH_TYPE=="RANDOM":
    FP_FRAC = 13
    FP_INT = 2
    FP_TOTAL = FP_FRAC + FP_INT + 1
    DATA_STRING_INSERT = "_RANDOM"
    VMAX = 1
else: raise NotImplementedError

SMALL_MODEL = True
if SMALL_MODEL:
    MODEL_STRING_INSERT = "_SMALL"
else:
    MODEL_STRING_INSERT = ""

REUSE_FACTOR = 32

print(f"IMG_COL_BITWIDTH: {IMG_COL_BITWIDTH}")
print(f"IMG_ROW_BITWIDTH: {IMG_ROW_BITWIDTH}")
print(f"FP_TOTAL: {FP_TOTAL}")
print(f"FP_INT: {FP_INT}")
print(f"FP_FRAC: {FP_FRAC}")
print(f"MODEL_STRING_INSERT: {MODEL_STRING_INSERT}")
print(f"DATA_STRING_INSERT: {DATA_STRING_INSERT}")


top_level_dir = os.path.join("tb_data", f"ap_fixed_{FP_TOTAL}_{FP_INT}", f"{IN_ROWS}x{IN_COLS}_to_{OUT_ROWS}x{OUT_COLS}x{NUM_CROPS}")
os.makedirs(top_level_dir, exist_ok=True)
# Out:
# IMG_COL_BITWIDTH: 9
# IMG_ROW_BITWIDTH: 8
# FP_TOTAL: 16
# FP_INT: 15
# FP_FRAC: 0
# MODEL_STRING_INSERT: _SMALL
# DATA_STRING_INSERT: _INDEX

# %% [markdown]
# Helper functions

# %%
def float_to_fixed_point(value: float, total_bits: int, fractional_bits: int) -> str:
    """
    Convert a float to a fixed-point binary representation.
    
    :param value: Float value to convert.
    :param total_bits: Total number of bits for the representation.
    :param fractional_bits: Number of fractional bits.
    :return: Fixed-point binary string.
    """
    scale = 2 ** fractional_bits
    fixed_point_value = int(round(value * scale))
    
    # Handle two's complement representation for negative numbers
    if fixed_point_value < 0:
        fixed_point_value = (1 << total_bits) + fixed_point_value
    
    return f"{fixed_point_value:0{total_bits}b}"


def fixed_point_to_float(binary: str, fractional_bits: int) -> float:
    """
    Convert a fixed-point binary representation to a float.
    
    :param binary: Fixed-point binary string.
    :param fractional_bits: Number of fractional bits.
    :return: Float value.
    """
    total_bits = len(binary)
    int_value = int(binary, 2)
    
    # Handle two's complement for negative numbers
    if int_value >= (1 << (total_bits - 1)):
        int_value -= (1 << total_bits)
    
    return int_value / (2 ** fractional_bits)

# %% [markdown]
# # 1. Generate, save testbench data

# %% [markdown]
# First, the un-cropped image

# %%
img_precrop_float = np.array([i for i in range(IN_ROWS*IN_COLS)]).reshape((IN_ROWS, IN_COLS)).astype(np.float32)
fpath_img_precrop = os.path.join(top_level_dir, f"img_precrop{DATA_STRING_INSERT}.bin")
with open(fpath_img_precrop, "w") as f:
    for row in img_precrop_float:
        for val in row:
            val_fixed = float_to_fixed_point(val, FP_TOTAL, FP_FRAC)
            f.write(f"{val_fixed}\n")

# %%
img_precrop_float_hex = [str(hex(int(i))) for i in range(IN_ROWS*IN_COLS)]
# for i, val in enumerate(img_precrop_float_hex):
#     if len(val) < 4:
#         new_val = "0"*(6-len(val))+val
#         img_precrop_float_hex[i] = new_val

fpath_img_precrop_hex = os.path.join(top_level_dir, f"img_precrop_hex{DATA_STRING_INSERT}.dat")

src_idx = 0
with open(fpath_img_precrop_hex, "w") as f:
    for i in range(IN_ROWS):
        if i!= 0:
            f.write("\n")
        for j in range(IN_COLS):
            val = img_precrop_float_hex[src_idx].replace("0x", "")
            print(f"pre_val: {val}")
            if len(val) < 4:
                new_val = "0"*(4-len(val))+val
                val = new_val
                print(f"post_val: {val}\n")

            f.write(f"{val} ")
            src_idx += 1
# Out:
# pre_val: 0
# post_val: 0000
#
# pre_val: 1
# post_val: 0001
#
# pre_val: 2
# post_val: 0002
#
# pre_val: 3
# post_val: 0003
#
# pre_val: 4
# post_val: 0004
#
# pre_val: 5
# post_val: 0005
#
# pre_val: 6
# post_val: 0006
#
# pre_val: 7
# post_val: 0007
#
# pre_val: 8
# post_val: 0008
#
# pre_val: 9
# post_val: 0009
#
# pre_val: a
# post_val: 000a
#
# pre_val: b
# post_val: 000b
#
# pre_val: c
# post_val: 000c
#
# pre_val: d
# post_val: 000d
#
# pre_val: e
# post_val: 000e
#
# pre_val: f
# post_val: 000f
#
# pre_val: 10
# post_val: 0010
#
# pre_val: 11
# post_val: 0011
#
# pre_val: 12
# post_val: 0012
#
# pre_val: 13
# post_val: 0013
#
# pre_val: 14
# post_val: 0014
#
# pre_val: 15
# post_val: 0015
#
# pre_val: 16
# post_val: 0016
#
# pre_val: 17
# post_val: 0017
#
# pre_val: 18
# post_val: 0018
#
# pre_val: 19
# post_val: 0019
#
# pre_val: 1a
# post_val: 001a
#
# pre_val: 1b
# post_val: 001b
#
# pre_val: 1c
# post_val: 001c
#
# pre_val: 1d
# post_val: 001d
#
# pre_val: 1e
# post_val: 001e
#
# pre_val: 1f
# post_val: 001f
#
# pre_val: 20
# post_val: 0020
#
# pre_val: 21
# post_val: 0021
#
# pre_val: 22
# post_val: 0022
#
# pre_val: 23
# post_val: 0023
#
# pre_val: 24
# post_val: 0024
#
# pre_val: 25
# post_val: 0025
#
# pre_val: 26
# post_val: 0026
#
# pre_val: 27
# post_val: 0027
#
# pre_val: 28
# post_val: 0028
#
# pre_val: 29
# post_val: 0029
#
# pre_val: 2a
# post_val: 002a
#
# pre_val: 2b
# post_val: 002b
#
# pre_val: 2c
# post_val: 002c
#
# pre_val: 2d
# post_val: 002d
#
# pre_val: 2e
# post_val: 002e
#
# pre_val: 2f
# post_val: 002f
#
# pre_val: 30
# post_val: 0030
#
# pre_val: 31
# post_val: 0031
#
# pre_val: 32
# post_val: 0032
#
# pre_val: 33
# post_val: 0033
#
# pre_val: 34
# post_val: 0034
#
# pre_val: 35
# post_val: 0035
#
# pre_val: 36
# post_val: 0036
#
# pre_val: 37
# post_val: 0037
#
# pre_val: 38
# post_val: 0038
#
# pre_val: 39
# post_val: 0039
#
# pre_val: 3a
# post_val: 003a
#
# pre_val: 3b
# post_val: 003b
#
# pre_val: 3c
# post_val: 003c
#
# pre_val: 3d
# post_val: 003d
#
# pre_val: 3e
# post_val: 003e
#
# pre_val: 3f
# post_val: 003f
#
# pre_val: 40
# post_val: 0040
#
# pre_val: 41
# post_val: 0041
#
# pre_val: 42
# post_val: 0042
#
# pre_val: 43
# post_val: 0043
#
# pre_val: 44
# post_val: 0044
#
# pre_val: 45
# post_val: 0045
#
# pre_val: 46
# post_val: 0046
#
# pre_val: 47
# post_val: 0047
#
# pre_val: 48
# post_val: 0048
#
# pre_val: 49
# post_val: 0049
#
# pre_val: 4a
# post_val: 004a
#
# pre_val: 4b
# post_val: 004b
#
# pre_val: 4c
# post_val: 004c
#
# pre_val: 4d
# post_val: 004d
#
# pre_val: 4e
# post_val: 004e
#
# pre_val: 4f
# post_val: 004f
#
# pre_val: 50
# post_val: 0050
#
# pre_val: 51
# post_val: 0051
#
# pre_val: 52
# post_val: 0052
#
# pre_val: 53
# post_val: 0053
#
# pre_val: 54
# post_val: 0054
#
# pre_val: 55
# post_val: 0055
#
# pre_val: 56
# post_val: 0056
#
# pre_val: 57
# post_val: 0057
#
# pre_val: 58
# post_val: 0058
#
# pre_val: 59
# post_val: 0059
#
# pre_val: 5a
# post_val: 005a
#
# pre_val: 5b
# post_val: 005b
#
# pre_val: 5c
# post_val: 005c
#
# pre_val: 5d
# post_val: 005d
#
# pre_val: 5e
# post_val: 005e
#
# pre_val: 5f
# post_val: 005f
#
# pre_val: 60
# post_val: 0060
#
# pre_val: 61
# post_val: 0061
#
# pre_val: 62
# post_val: 0062
#
# pre_val: 63
# post_val: 0063
#
# pre_val: 64
# post_val: 0064
#
# pre_val: 65
# post_val: 0065
#
# pre_val: 66
# post_val: 0066
#
# pre_val: 67
# post_val: 0067
#
# pre_val: 68
# post_val: 0068
#
# pre_val: 69
# post_val: 0069
#
# pre_val: 6a
# post_val: 006a
#
# pre_val: 6b
# post_val: 006b
#
# pre_val: 6c
# post_val: 006c
#
# pre_val: 6d
# post_val: 006d
#
# pre_val: 6e
# post_val: 006e
#
# pre_val: 6f
# post_val: 006f
#
# pre_val: 70
# post_val: 0070
#
# pre_val: 71
# post_val: 0071
#
# pre_val: 72
# post_val: 0072
#
# pre_val: 73
# post_val: 0073
#
# pre_val: 74
# post_val: 0074
#
# pre_val: 75
# post_val: 0075
#
# pre_val: 76
# post_val: 0076
#
# pre_val: 77
# post_val: 0077
#
# pre_val: 78
# post_val: 0078
#
# pre_val: 79
# post_val: 0079
#
# pre_val: 7a
# post_val: 007a
#
# pre_val: 7b
# post_val: 007b
#
# pre_val: 7c
# post_val: 007c
#
# pre_val: 7d
# post_val: 007d
#
# pre_val: 7e
# post_val: 007e
#
# pre_val: 7f
# post_val: 007f
#
# pre_val: 80
# post_val: 0080
#
# pre_val: 81
# post_val: 0081
#
# pre_val: 82
# post_val: 0082
#
# pre_val: 83
# post_val: 0083
#
# pre_val: 84
# post_val: 0084
#
# pre_val: 85
# post_val: 0085
#
# pre_val: 86
# post_val: 0086
#
# pre_val: 87
# post_val: 0087
#
# pre_val: 88
# post_val: 0088
#
# pre_val: 89
# post_val: 0089
#
# pre_val: 8a
# post_val: 008a
#
# pre_val: 8b
# post_val: 008b
#
# pre_val: 8c
# post_val: 008c
#
# pre_val: 8d
# post_val: 008d
#
# pre_val: 8e
# post_val: 008e
#
# pre_val: 8f
# post_val: 008f
#
# pre_val: 90
# post_val: 0090
#
# pre_val: 91
# post_val: 0091
#
# pre_val: 92
# post_val: 0092
#
# pre_val: 93
# post_val: 0093
#
# pre_val: 94
# post_val: 0094
#
# pre_val: 95
# post_val: 0095
#
# pre_val: 96
# post_val: 0096
#
# pre_val: 97
# post_val: 0097
#
# pre_val: 98
# post_val: 0098
#
# pre_val: 99
# post_val: 0099
#
# pre_val: 9a
# post_val: 009a
#
# pre_val: 9b
# post_val: 009b
#
# pre_val: 9c
# post_val: 009c
#
# pre_val: 9d
# post_val: 009d
#
# pre_val: 9e
# post_val: 009e
#
# pre_val: 9f
# post_val: 009f
#
# pre_val: a0
# post_val: 00a0
#
# pre_val: a1
# post_val: 00a1
#
# pre_val: a2
# post_val: 00a2
#
# pre_val: a3
# post_val: 00a3
#
# pre_val: a4
# post_val: 00a4
#
# pre_val: a5
# post_val: 00a5
#
# pre_val: a6
# post_val: 00a6
#
# pre_val: a7
# post_val: 00a7
#
# pre_val: a8
# post_val: 00a8
#
# pre_val: a9
# post_val: 00a9
#
# pre_val: aa
# post_val: 00aa
#
# pre_val: ab
# post_val: 00ab
#
# pre_val: ac
# post_val: 00ac
#
# pre_val: ad
# post_val: 00ad
#
# pre_val: ae
# post_val: 00ae
#
# pre_val: af
# post_val: 00af
#
# pre_val: b0
# post_val: 00b0
#
# pre_val: b1
# post_val: 00b1
#
# pre_val: b2
# post_val: 00b2
#
# pre_val: b3
# post_val: 00b3
#
# pre_val: b4
# post_val: 00b4
#
# pre_val: b5
# post_val: 00b5
#
# pre_val: b6
# post_val: 00b6
#
# pre_val: b7
# post_val: 00b7
#
# pre_val: b8
# post_val: 00b8
#
# pre_val: b9
# post_val: 00b9
#
# pre_val: ba
# post_val: 00ba
#
# pre_val: bb
# post_val: 00bb
#
# pre_val: bc
# post_val: 00bc
#
# pre_val: bd
# post_val: 00bd
#
# pre_val: be
# post_val: 00be
#
# pre_val: bf
# post_val: 00bf
#
# pre_val: c0
# post_val: 00c0
#
# pre_val: c1
# post_val: 00c1
#
# pre_val: c2
# post_val: 00c2
#
# pre_val: c3
# post_val: 00c3
#
# pre_val: c4
# post_val: 00c4
#
# pre_val: c5
# post_val: 00c5
#
# pre_val: c6
# post_val: 00c6
#
# pre_val: c7
# post_val: 00c7
#
# pre_val: c8
# post_val: 00c8
#
# pre_val: c9
# post_val: 00c9
#
# pre_val: ca
# post_val: 00ca
#
# pre_val: cb
# post_val: 00cb
#
# pre_val: cc
# post_val: 00cc
#
# pre_val: cd
# post_val: 00cd
#
# pre_val: ce
# post_val: 00ce
#
# pre_val: cf
# post_val: 00cf
#
# pre_val: d0
# post_val: 00d0
#
# pre_val: d1
# post_val: 00d1
#
# pre_val: d2
# post_val: 00d2
#
# pre_val: d3
# post_val: 00d3
#
# pre_val: d4
# post_val: 00d4
#
# pre_val: d5
# post_val: 00d5
#
# pre_val: d6
# post_val: 00d6
#
# pre_val: d7
# post_val: 00d7
#
# pre_val: d8
# post_val: 00d8
#
# pre_val: d9
# post_val: 00d9
#
# pre_val: da
# post_val: 00da
#
# pre_val: db
# post_val: 00db
#
# pre_val: dc
# post_val: 00dc
#
# pre_val: dd
# post_val: 00dd
#
# pre_val: de
# post_val: 00de
#
# pre_val: df
# post_val: 00df
#
# pre_val: e0
# post_val: 00e0
#
# pre_val: e1
# post_val: 00e1
#
# pre_val: e2
# post_val: 00e2
#
# pre_val: e3
# post_val: 00e3
#
# pre_val: e4
# post_val: 00e4
#
# pre_val: e5
# post_val: 00e5
#
# pre_val: e6
# post_val: 00e6
#
# pre_val: e7
# post_val: 00e7
#
# pre_val: e8
# post_val: 00e8
#
# pre_val: e9
# post_val: 00e9
#
# pre_val: ea
# post_val: 00ea
#
# pre_val: eb
# post_val: 00eb
#
# pre_val: ec
# post_val: 00ec
#
# pre_val: ed
# post_val: 00ed
#
# pre_val: ee
# post_val: 00ee
#
# pre_val: ef
# post_val: 00ef
#
# pre_val: f0
# post_val: 00f0
#
# pre_val: f1
# post_val: 00f1
#
# pre_val: f2
# post_val: 00f2
#
# pre_val: f3
# post_val: 00f3
#
# pre_val: f4
# post_val: 00f4
#
# pre_val: f5
# post_val: 00f5
#
# pre_val: f6
# post_val: 00f6
#
# pre_val: f7
# post_val: 00f7
#
# pre_val: f8
# post_val: 00f8
#
# pre_val: f9
# post_val: 00f9
#
# pre_val: fa
# post_val: 00fa
#
# pre_val: fb
# post_val: 00fb
#
# pre_val: fc
# post_val: 00fc
#
# pre_val: fd
# post_val: 00fd
#
# pre_val: fe
# post_val: 00fe
#
# pre_val: ff
# post_val: 00ff
#
# pre_val: 100
# post_val: 0100
#
# pre_val: 101
# post_val: 0101
#
# pre_val: 102
# post_val: 0102
#
# pre_val: 103
# post_val: 0103
#
# pre_val: 104
# post_val: 0104
#
# pre_val: 105
# post_val: 0105
#
# pre_val: 106
# post_val: 0106
#
# pre_val: 107
# post_val: 0107
#
# pre_val: 108
# post_val: 0108
#
# pre_val: 109
# post_val: 0109
#
# pre_val: 10a
# post_val: 010a
#
# pre_val: 10b
# post_val: 010b
#
# pre_val: 10c
# post_val: 010c
#
# pre_val: 10d
# post_val: 010d
#
# pre_val: 10e
# post_val: 010e
#
# pre_val: 10f
# post_val: 010f
#
# pre_val: 110
# post_val: 0110
#
# pre_val: 111
# post_val: 0111
#
# pre_val: 112
# post_val: 0112
#
# pre_val: 113
# post_val: 0113
#
# pre_val: 114
# post_val: 0114
#
# pre_val: 115
# post_val: 0115
#
# pre_val: 116
# post_val: 0116
#
# pre_val: 117
# post_val: 0117
#
# pre_val: 118
# post_val: 0118
#
# pre_val: 119
# post_val: 0119
#
# pre_val: 11a
# post_val: 011a
#
# pre_val: 11b
# post_val: 011b
#
# pre_val: 11c
# post_val: 011c
#
# pre_val: 11d
# post_val: 011d
#
# pre_val: 11e
# post_val: 011e
#
# pre_val: 11f
# post_val: 011f
#
# pre_val: 120
# post_val: 0120
#
# pre_val: 121
# post_val: 0121
#
# pre_val: 122
# post_val: 0122
#
# pre_val: 123
# post_val: 0123
#
# pre_val: 124
# post_val: 0124
#
# pre_val: 125
# post_val: 0125
#
# pre_val: 126
# post_val: 0126
#
# pre_val: 127
# post_val: 0127
#
# pre_val: 128
# post_val: 0128
#
# pre_val: 129
# post_val: 0129
#
# pre_val: 12a
# post_val: 012a
#
# pre_val: 12b
# post_val: 012b
#
# pre_val: 12c
# post_val: 012c
#
# pre_val: 12d
# post_val: 012d
#
# pre_val: 12e
# post_val: 012e
#
# pre_val: 12f
# post_val: 012f
#
# pre_val: 130
# post_val: 0130
#
# pre_val: 131
# post_val: 0131
#
# pre_val: 132
# post_val: 0132
#
# pre_val: 133
# post_val: 0133
#
# pre_val: 134
# post_val: 0134
#
# pre_val: 135
# post_val: 0135
#
# pre_val: 136
# post_val: 0136
#
# pre_val: 137
# post_val: 0137
#
# pre_val: 138
# post_val: 0138
#
# pre_val: 139
# post_val: 0139
#
# pre_val: 13a
# post_val: 013a
#
# pre_val: 13b
# post_val: 013b
#
# pre_val: 13c
# post_val: 013c
#
# pre_val: 13d
# post_val: 013d
#
# pre_val: 13e
# post_val: 013e
#
# pre_val: 13f
# post_val: 013f
#
# pre_val: 140
# post_val: 0140
#
# pre_val: 141
# post_val: 0141
#
# pre_val: 142
# post_val: 0142
#
# pre_val: 143
# post_val: 0143
#
# pre_val: 144
# post_val: 0144
#
# pre_val: 145
# post_val: 0145
#
# pre_val: 146
# post_val: 0146
#
# pre_val: 147
# post_val: 0147
#
# pre_val: 148
# post_val: 0148
#
# pre_val: 149
# post_val: 0149
#
# pre_val: 14a
# post_val: 014a
#
# pre_val: 14b
# post_val: 014b
#
# pre_val: 14c
# post_val: 014c
#
# pre_val: 14d
# post_val: 014d
#
# pre_val: 14e
# post_val: 014e
#
# pre_val: 14f
# post_val: 014f
#
# pre_val: 150
# post_val: 0150
#
# pre_val: 151
# post_val: 0151
#
# pre_val: 152
# post_val: 0152
#
# pre_val: 153
# post_val: 0153
#
# pre_val: 154
# post_val: 0154
#
# pre_val: 155
# post_val: 0155
#
# pre_val: 156
# post_val: 0156
#
# pre_val: 157
# post_val: 0157
#
# pre_val: 158
# post_val: 0158
#
# pre_val: 159
# post_val: 0159
#
# pre_val: 15a
# post_val: 015a
#
# pre_val: 15b
# post_val: 015b
#
# pre_val: 15c
# post_val: 015c
#
# pre_val: 15d
# post_val: 015d
#
# pre_val: 15e
# post_val: 015e
#
# pre_val: 15f
# post_val: 015f
#
# pre_val: 160
# post_val: 0160
#
# pre_val: 161
# post_val: 0161
#
# pre_val: 162
# post_val: 0162
#
# pre_val: 163
# post_val: 0163
#
# pre_val: 164
# post_val: 0164
#
# pre_val: 165
# post_val: 0165
#
# pre_val: 166
# post_val: 0166
#
# pre_val: 167
# post_val: 0167
#
# pre_val: 168
# post_val: 0168
#
# pre_val: 169
# post_val: 0169
#
# pre_val: 16a
# post_val: 016a
#
# pre_val: 16b
# post_val: 016b
#
# pre_val: 16c
# post_val: 016c
#
# pre_val: 16d
# post_val: 016d
#
# pre_val: 16e
# post_val: 016e
#
# pre_val: 16f
# post_val: 016f
#
# pre_val: 170
# post_val: 0170
#
# pre_val: 171
# post_val: 0171
#
# pre_val: 172
# post_val: 0172
#
# pre_val: 173
# post_val: 0173
#
# pre_val: 174
# post_val: 0174
#
# pre_val: 175
# post_val: 0175
#
# pre_val: 176
# post_val: 0176
#
# pre_val: 177
# post_val: 0177
#
# pre_val: 178
# post_val: 0178
#
# pre_val: 179
# post_val: 0179
#
# pre_val: 17a
# post_val: 017a
#
# pre_val: 17b
# post_val: 017b
#
# pre_val: 17c
# post_val: 017c
#
# pre_val: 17d
# post_val: 017d
#
# pre_val: 17e
# post_val: 017e
#
# pre_val: 17f
# post_val: 017f
#
# pre_val: 180
# post_val: 0180
#
# pre_val: 181
# post_val: 0181
#
# pre_val: 182
# post_val: 0182
#
# pre_val: 183
# post_val: 0183
#
# pre_val: 184
# post_val: 0184
#
# pre_val: 185
# post_val: 0185
#
# pre_val: 186
# post_val: 0186
#
# pre_val: 187
# post_val: 0187
#
# pre_val: 188
# post_val: 0188
#
# pre_val: 189
# post_val: 0189
#
# pre_val: 18a
# post_val: 018a
#
# pre_val: 18b
# post_val: 018b
#
# pre_val: 18c
# post_val: 018c
#
# pre_val: 18d
# post_val: 018d
#
# pre_val: 18e
# post_val: 018e
#
# pre_val: 18f
# post_val: 018f
#
# pre_val: 190
# post_val: 0190
#
# pre_val: 191
# post_val: 0191
#
# pre_val: 192
# post_val: 0192
#
# pre_val: 193
# post_val: 0193
#
# pre_val: 194
# post_val: 0194
#
# pre_val: 195
# post_val: 0195
#
# pre_val: 196
# post_val: 0196
#
# pre_val: 197
# post_val: 0197
#
# pre_val: 198
# post_val: 0198
#
# pre_val: 199
# post_val: 0199
#
# pre_val: 19a
# post_val: 019a
#
# pre_val: 19b
# post_val: 019b
#
# pre_val: 19c
# post_val: 019c
#
# pre_val: 19d
# post_val: 019d
#
# pre_val: 19e
# post_val: 019e
#
# pre_val: 19f
# post_val: 019f
#
# pre_val: 1a0
# post_val: 01a0
#
# pre_val: 1a1
# post_val: 01a1
#
# pre_val: 1a2
# post_val: 01a2
#
# pre_val: 1a3
# post_val: 01a3
#
# pre_val: 1a4
# post_val: 01a4
#
# pre_val: 1a5
# post_val: 01a5
#
# pre_val: 1a6
# post_val: 01a6
#
# pre_val: 1a7
# post_val: 01a7
#
# pre_val: 1a8
# post_val: 01a8
#
# pre_val: 1a9
# post_val: 01a9
#
# pre_val: 1aa
# post_val: 01aa
#
# pre_val: 1ab
# post_val: 01ab
#
# pre_val: 1ac
# post_val: 01ac
#
# pre_val: 1ad
# post_val: 01ad
#
# pre_val: 1ae
# post_val: 01ae
#
# pre_val: 1af
# post_val: 01af
#
# pre_val: 1b0
# post_val: 01b0
#
# pre_val: 1b1
# post_val: 01b1
#
# pre_val: 1b2
# post_val: 01b2
#
# pre_val: 1b3
# post_val: 01b3
#
# pre_val: 1b4
# post_val: 01b4
#
# pre_val: 1b5
# post_val: 01b5
#
# pre_val: 1b6
# post_val: 01b6
#
# pre_val: 1b7
# post_val: 01b7
#
# pre_val: 1b8
# post_val: 01b8
#
# pre_val: 1b9
# post_val: 01b9
#
# pre_val: 1ba
# post_val: 01ba
#
# pre_val: 1bb
# post_val: 01bb
#
# pre_val: 1bc
# post_val: 01bc
#
# pre_val: 1bd
# post_val: 01bd
#
# pre_val: 1be
# post_val: 01be
#
# pre_val: 1bf
# post_val: 01bf
#
# pre_val: 1c0
# post_val: 01c0
#
# pre_val: 1c1
# post_val: 01c1
#
# pre_val: 1c2
# post_val: 01c2
#
# pre_val: 1c3
# post_val: 01c3
#
# pre_val: 1c4
# post_val: 01c4
#
# pre_val: 1c5
# post_val: 01c5
#
# pre_val: 1c6
# post_val: 01c6
#
# pre_val: 1c7
# post_val: 01c7
#
# pre_val: 1c8
# post_val: 01c8
#
# pre_val: 1c9
# post_val: 01c9
#
# pre_val: 1ca
# post_val: 01ca
#
# pre_val: 1cb
# post_val: 01cb
#
# pre_val: 1cc
# post_val: 01cc
#
# pre_val: 1cd
# post_val: 01cd
#
# pre_val: 1ce
# post_val: 01ce
#
# pre_val: 1cf
# post_val: 01cf
#
# pre_val: 1d0
# post_val: 01d0
#
# pre_val: 1d1
# post_val: 01d1
#
# pre_val: 1d2
# post_val: 01d2
#
# pre_val: 1d3
# post_val: 01d3
#
# pre_val: 1d4
# post_val: 01d4
#
# pre_val: 1d5
# post_val: 01d5
#
# pre_val: 1d6
# post_val: 01d6
#
# pre_val: 1d7
# post_val: 01d7
#
# pre_val: 1d8
# post_val: 01d8
#
# pre_val: 1d9
# post_val: 01d9
#
# pre_val: 1da
# post_val: 01da
#
# pre_val: 1db
# post_val: 01db
#
# pre_val: 1dc
# post_val: 01dc
#
# pre_val: 1dd
# post_val: 01dd
#
# pre_val: 1de
# post_val: 01de
#
# pre_val: 1df
# post_val: 01df
#
# pre_val: 1e0
# post_val: 01e0
#
# pre_val: 1e1
# post_val: 01e1
#
# pre_val: 1e2
# post_val: 01e2
#
# pre_val: 1e3
# post_val: 01e3
#
# pre_val: 1e4
# post_val: 01e4
#
# pre_val: 1e5
# post_val: 01e5
#
# pre_val: 1e6
# post_val: 01e6
#
# pre_val: 1e7
# post_val: 01e7
#
# pre_val: 1e8
# post_val: 01e8
#
# pre_val: 1e9
# post_val: 01e9
#
# pre_val: 1ea
# post_val: 01ea
#
# pre_val: 1eb
# post_val: 01eb
#
# pre_val: 1ec
# post_val: 01ec
#
# pre_val: 1ed
# post_val: 01ed
#
# pre_val: 1ee
# post_val: 01ee
#
# pre_val: 1ef
# post_val: 01ef
#
# pre_val: 1f0
# post_val: 01f0
#
# pre_val: 1f1
# post_val: 01f1
#
# pre_val: 1f2
# post_val: 01f2
#
# pre_val: 1f3
# post_val: 01f3
#
# pre_val: 1f4
# post_val: 01f4
#
# pre_val: 1f5
# post_val: 01f5
#
# pre_val: 1f6
# post_val: 01f6
#
# pre_val: 1f7
# post_val: 01f7
#
# pre_val: 1f8
# post_val: 01f8
#
# pre_val: 1f9
# post_val: 01f9
#
# pre_val: 1fa
# post_val: 01fa
#
# pre_val: 1fb
# post_val: 01fb
#
# pre_val: 1fc
# post_val: 01fc
#
# pre_val: 1fd
# post_val: 01fd
#
# pre_val: 1fe
# post_val: 01fe
#
# pre_val: 1ff
# post_val: 01ff
#
# pre_val: 200
# post_val: 0200
#
# pre_val: 201
# post_val: 0201
#
# pre_val: 202
# post_val: 0202
#
# pre_val: 203
# post_val: 0203
#
# pre_val: 204
# post_val: 0204
#
# pre_val: 205
# post_val: 0205
#
# pre_val: 206
# post_val: 0206
#
# pre_val: 207
# post_val: 0207
#
# pre_val: 208
# post_val: 0208
#
# pre_val: 209
# post_val: 0209
#
# pre_val: 20a
# post_val: 020a
#
# pre_val: 20b
# post_val: 020b
#
# pre_val: 20c
# post_val: 020c
#
# pre_val: 20d
# post_val: 020d
#
# pre_val: 20e
# post_val: 020e
#
# pre_val: 20f
# post_val: 020f
#
# pre_val: 210
# post_val: 0210
#
# pre_val: 211
# post_val: 0211
#
# pre_val: 212
# post_val: 0212
#
# pre_val: 213
# post_val: 0213
#
# pre_val: 214
# post_val: 0214
#
# pre_val: 215
# post_val: 0215
#
# pre_val: 216
# post_val: 0216
#
# pre_val: 217
# post_val: 0217
#
# pre_val: 218
# post_val: 0218
#
# pre_val: 219
# post_val: 0219
#
# pre_val: 21a
# post_val: 021a
#
# pre_val: 21b
# post_val: 021b
#
# pre_val: 21c
# post_val: 021c
#
# pre_val: 21d
# post_val: 021d
#
# pre_val: 21e
# post_val: 021e
#
# pre_val: 21f
# post_val: 021f
#
# pre_val: 220
# post_val: 0220
#
# pre_val: 221
# post_val: 0221
#
# pre_val: 222
# post_val: 0222
#
# pre_val: 223
# post_val: 0223
#
# pre_val: 224
# post_val: 0224
#
# pre_val: 225
# post_val: 0225
#
# pre_val: 226
# post_val: 0226
#
# pre_val: 227
# post_val: 0227
#
# pre_val: 228
# post_val: 0228
#
# pre_val: 229
# post_val: 0229
#
# pre_val: 22a
# post_val: 022a
#
# pre_val: 22b
# post_val: 022b
#
# pre_val: 22c
# post_val: 022c
#
# pre_val: 22d
# post_val: 022d
#
# pre_val: 22e
# post_val: 022e
#
# pre_val: 22f
# post_val: 022f
#
# pre_val: 230
# post_val: 0230
#
# pre_val: 231
# post_val: 0231
#
# pre_val: 232
# post_val: 0232
#
# pre_val: 233
# post_val: 0233
#
# pre_val: 234
# post_val: 0234
#
# pre_val: 235
# post_val: 0235
#
# pre_val: 236
# post_val: 0236
#
# pre_val: 237
# post_val: 0237
#
# pre_val: 238
# post_val: 0238
#
# pre_val: 239
# post_val: 0239
#
# pre_val: 23a
# post_val: 023a
#
# pre_val: 23b
# post_val: 023b
#
# pre_val: 23c
# post_val: 023c
#
# pre_val: 23d
# post_val: 023d
#
# pre_val: 23e
# post_val: 023e
#
# pre_val: 23f
# post_val: 023f
#
# pre_val: 240
# post_val: 0240
#
# pre_val: 241
# post_val: 0241
#
# pre_val: 242
# post_val: 0242
#
# pre_val: 243
# post_val: 0243
#
# pre_val: 244
# post_val: 0244
#
# pre_val: 245
# post_val: 0245
#
# pre_val: 246
# post_val: 0246
#
# pre_val: 247
# post_val: 0247
#
# pre_val: 248
# post_val: 0248
#
# pre_val: 249
# post_val: 0249
#
# pre_val: 24a
# post_val: 024a
#
# pre_val: 24b
# post_val: 024b
#
# pre_val: 24c
# post_val: 024c
#
# pre_val: 24d
# post_val: 024d
#
# pre_val: 24e
# post_val: 024e
#
# pre_val: 24f
# post_val: 024f
#
# pre_val: 250
# post_val: 0250
#
# pre_val: 251
# post_val: 0251
#
# pre_val: 252
# post_val: 0252
#
# pre_val: 253
# post_val: 0253
#
# pre_val: 254
# post_val: 0254
#
# pre_val: 255
# post_val: 0255
#
# pre_val: 256
# post_val: 0256
#
# pre_val: 257
# post_val: 0257
#
# pre_val: 258
# post_val: 0258
#
# pre_val: 259
# post_val: 0259
#
# pre_val: 25a
# post_val: 025a
#
# pre_val: 25b
# post_val: 025b
#
# pre_val: 25c
# post_val: 025c
#
# pre_val: 25d
# post_val: 025d
#
# pre_val: 25e
# post_val: 025e
#
# pre_val: 25f
# post_val: 025f
#
# pre_val: 260
# post_val: 0260
#
# pre_val: 261
# post_val: 0261
#
# pre_val: 262
# post_val: 0262
#
# pre_val: 263
# post_val: 0263
#
# pre_val: 264
# post_val: 0264
#
# pre_val: 265
# post_val: 0265
#
# pre_val: 266
# post_val: 0266
#
# pre_val: 267
# post_val: 0267
#
# pre_val: 268
# post_val: 0268
#
# pre_val: 269
# post_val: 0269
#
# pre_val: 26a
# post_val: 026a
#
# pre_val: 26b
# post_val: 026b
#
# pre_val: 26c
# post_val: 026c
#
# pre_val: 26d
# post_val: 026d
#
# pre_val: 26e
# post_val: 026e
#
# pre_val: 26f
# post_val: 026f
#
# pre_val: 270
# post_val: 0270
#
# pre_val: 271
# post_val: 0271
#
# pre_val: 272
# post_val: 0272
#
# pre_val: 273
# post_val: 0273
#
# pre_val: 274
# post_val: 0274
#
# pre_val: 275
# post_val: 0275
#
# pre_val: 276
# post_val: 0276
#
# pre_val: 277
# post_val: 0277
#
# pre_val: 278
# post_val: 0278
#
# pre_val: 279
# post_val: 0279
#
# pre_val: 27a
# post_val: 027a
#
# pre_val: 27b
# post_val: 027b
#
# pre_val: 27c
# post_val: 027c
#
# pre_val: 27d
# post_val: 027d
#
# pre_val: 27e
# post_val: 027e
#
# pre_val: 27f
# post_val: 027f
#
# pre_val: 280
# post_val: 0280
#
# pre_val: 281
# post_val: 0281
#
# pre_val: 282
# post_val: 0282
#
# pre_val: 283
# post_val: 0283
#
# pre_val: 284
# post_val: 0284
#
# pre_val: 285
# post_val: 0285
#
# pre_val: 286
# post_val: 0286
#
# pre_val: 287
# post_val: 0287
#
# pre_val: 288
# post_val: 0288
#
# pre_val: 289
# post_val: 0289
#
# pre_val: 28a
# post_val: 028a
#
# pre_val: 28b
# post_val: 028b
#
# pre_val: 28c
# post_val: 028c
#
# pre_val: 28d
# post_val: 028d
#
# pre_val: 28e
# post_val: 028e
#
# pre_val: 28f
# post_val: 028f
#
# pre_val: 290
# post_val: 0290
#
# pre_val: 291
# post_val: 0291
#
# pre_val: 292
# post_val: 0292
#
# pre_val: 293
# post_val: 0293
#
# pre_val: 294
# post_val: 0294
#
# pre_val: 295
# post_val: 0295
#
# pre_val: 296
# post_val: 0296
#
# pre_val: 297
# post_val: 0297
#
# pre_val: 298
# post_val: 0298
#
# pre_val: 299
# post_val: 0299
#
# pre_val: 29a
# post_val: 029a
#
# pre_val: 29b
# post_val: 029b
#
# pre_val: 29c
# post_val: 029c
#
# pre_val: 29d
# post_val: 029d
#
# pre_val: 29e
# post_val: 029e
#
# pre_val: 29f
# post_val: 029f
#
# pre_val: 2a0
# post_val: 02a0
#
# pre_val: 2a1
# post_val: 02a1
#
# pre_val: 2a2
# post_val: 02a2
#
# pre_val: 2a3
# post_val: 02a3
#
# pre_val: 2a4
# post_val: 02a4
#
# pre_val: 2a5
# post_val: 02a5
#
# pre_val: 2a6
# post_val: 02a6
#
# pre_val: 2a7
# post_val: 02a7
#
# pre_val: 2a8
# post_val: 02a8
#
# pre_val: 2a9
# post_val: 02a9
#
# pre_val: 2aa
# post_val: 02aa
#
# pre_val: 2ab
# post_val: 02ab
#
# pre_val: 2ac
# post_val: 02ac
#
# pre_val: 2ad
# post_val: 02ad
#
# pre_val: 2ae
# post_val: 02ae
#
# pre_val: 2af
# post_val: 02af
#
# pre_val: 2b0
# post_val: 02b0
#
# pre_val: 2b1
# post_val: 02b1
#
# pre_val: 2b2
# post_val: 02b2
#
# pre_val: 2b3
# post_val: 02b3
#
# pre_val: 2b4
# post_val: 02b4
#
# pre_val: 2b5
# post_val: 02b5
#
# pre_val: 2b6
# post_val: 02b6
#
# pre_val: 2b7
# post_val: 02b7
#
# pre_val: 2b8
# post_val: 02b8
#
# pre_val: 2b9
# post_val: 02b9
#
# pre_val: 2ba
# post_val: 02ba
#
# pre_val: 2bb
# post_val: 02bb
#
# pre_val: 2bc
# post_val: 02bc
#
# pre_val: 2bd
# post_val: 02bd
#
# pre_val: 2be
# post_val: 02be
#
# pre_val: 2bf
# post_val: 02bf
#
# pre_val: 2c0
# post_val: 02c0
#
# pre_val: 2c1
# post_val: 02c1
#
# pre_val: 2c2
# post_val: 02c2
#
# pre_val: 2c3
# post_val: 02c3
#
# pre_val: 2c4
# post_val: 02c4
#
# pre_val: 2c5
# post_val: 02c5
#
# pre_val: 2c6
# post_val: 02c6
#
# pre_val: 2c7
# post_val: 02c7
#
# pre_val: 2c8
# post_val: 02c8
#
# pre_val: 2c9
# post_val: 02c9
#
# pre_val: 2ca
# post_val: 02ca
#
# pre_val: 2cb
# post_val: 02cb
#
# pre_val: 2cc
# post_val: 02cc
#
# pre_val: 2cd
# post_val: 02cd
#
# pre_val: 2ce
# post_val: 02ce
#
# pre_val: 2cf
# post_val: 02cf
#
# pre_val: 2d0
# post_val: 02d0
#
# pre_val: 2d1
# post_val: 02d1
#
# pre_val: 2d2
# post_val: 02d2
#
# pre_val: 2d3
# post_val: 02d3
#
# pre_val: 2d4
# post_val: 02d4
#
# pre_val: 2d5
# post_val: 02d5
#
# pre_val: 2d6
# post_val: 02d6
#
# pre_val: 2d7
# post_val: 02d7
#
# pre_val: 2d8
# post_val: 02d8
#
# pre_val: 2d9
# post_val: 02d9
#
# pre_val: 2da
# post_val: 02da
#
# pre_val: 2db
# post_val: 02db
#
# pre_val: 2dc
# post_val: 02dc
#
# pre_val: 2dd
# post_val: 02dd
#
# pre_val: 2de
# post_val: 02de
#
# pre_val: 2df
# post_val: 02df
#
# pre_val: 2e0
# post_val: 02e0
#
# pre_val: 2e1
# post_val: 02e1
#
# pre_val: 2e2
# post_val: 02e2
#
# pre_val: 2e3
# post_val: 02e3
#
# pre_val: 2e4
# post_val: 02e4
#
# pre_val: 2e5
# post_val: 02e5
#
# pre_val: 2e6
# post_val: 02e6
#
# pre_val: 2e7
# post_val: 02e7
#
# pre_val: 2e8
# post_val: 02e8
#
# pre_val: 2e9
# post_val: 02e9
#
# pre_val: 2ea
# post_val: 02ea
#
# pre_val: 2eb
# post_val: 02eb
#
# pre_val: 2ec
# post_val: 02ec
#
# pre_val: 2ed
# post_val: 02ed
#
# pre_val: 2ee
# post_val: 02ee
#
# pre_val: 2ef
# post_val: 02ef
#
# pre_val: 2f0
# post_val: 02f0
#
# pre_val: 2f1
# post_val: 02f1
#
# pre_val: 2f2
# post_val: 02f2
#
# pre_val: 2f3
# post_val: 02f3
#
# pre_val: 2f4
# post_val: 02f4
#
# pre_val: 2f5
# post_val: 02f5
#
# pre_val: 2f6
# post_val: 02f6
#
# pre_val: 2f7
# post_val: 02f7
#
# pre_val: 2f8
# post_val: 02f8
#
# pre_val: 2f9
# post_val: 02f9
#
# pre_val: 2fa
# post_val: 02fa
#
# pre_val: 2fb
# post_val: 02fb
#
# pre_val: 2fc
# post_val: 02fc
#
# pre_val: 2fd
# post_val: 02fd
#
# pre_val: 2fe
# post_val: 02fe
#
# pre_val: 2ff
# post_val: 02ff
#
# pre_val: 300
# post_val: 0300
#
# pre_val: 301
# post_val: 0301
#
# pre_val: 302
# post_val: 0302
#
# pre_val: 303
# post_val: 0303
#
# pre_val: 304
# post_val: 0304
#
# pre_val: 305
# post_val: 0305
#
# pre_val: 306
# post_val: 0306
#
# pre_val: 307
# post_val: 0307
#
# pre_val: 308
# post_val: 0308
#
# pre_val: 309
# post_val: 0309
#
# pre_val: 30a
# post_val: 030a
#
# pre_val: 30b
# post_val: 030b
#
# pre_val: 30c
# post_val: 030c
#
# pre_val: 30d
# post_val: 030d
#
# pre_val: 30e
# post_val: 030e
#
# pre_val: 30f
# post_val: 030f
#
# pre_val: 310
# post_val: 0310
#
# pre_val: 311
# post_val: 0311
#
# pre_val: 312
# post_val: 0312
#
# pre_val: 313
# post_val: 0313
#
# pre_val: 314
# post_val: 0314
#
# pre_val: 315
# post_val: 0315
#
# pre_val: 316
# post_val: 0316
#
# pre_val: 317
# post_val: 0317
#
# pre_val: 318
# post_val: 0318
#
# pre_val: 319
# post_val: 0319
#
# pre_val: 31a
# post_val: 031a
#
# pre_val: 31b
# post_val: 031b
#
# pre_val: 31c
# post_val: 031c
#
# pre_val: 31d
# post_val: 031d
#
# pre_val: 31e
# post_val: 031e
#
# pre_val: 31f
# post_val: 031f
#
# pre_val: 320
# post_val: 0320
#
# pre_val: 321
# post_val: 0321
#
# pre_val: 322
# post_val: 0322
#
# pre_val: 323
# post_val: 0323
#
# pre_val: 324
# post_val: 0324
#
# pre_val: 325
# post_val: 0325
#
# pre_val: 326
# post_val: 0326
#
# pre_val: 327
# post_val: 0327
#
# pre_val: 328
# post_val: 0328
#
# pre_val: 329
# post_val: 0329
#
# pre_val: 32a
# post_val: 032a
#
# pre_val: 32b
# post_val: 032b
#
# pre_val: 32c
# post_val: 032c
#
# pre_val: 32d
# post_val: 032d
#
# pre_val: 32e
# post_val: 032e
#
# pre_val: 32f
# post_val: 032f
#
# pre_val: 330
# post_val: 0330
#
# pre_val: 331
# post_val: 0331
#
# pre_val: 332
# post_val: 0332
#
# pre_val: 333
# post_val: 0333
#
# pre_val: 334
# post_val: 0334
#
# pre_val: 335
# post_val: 0335
#
# pre_val: 336
# post_val: 0336
#
# pre_val: 337
# post_val: 0337
#
# pre_val: 338
# post_val: 0338
#
# pre_val: 339
# post_val: 0339
#
# pre_val: 33a
# post_val: 033a
#
# pre_val: 33b
# post_val: 033b
#
# pre_val: 33c
# post_val: 033c
#
# pre_val: 33d
# post_val: 033d
#
# pre_val: 33e
# post_val: 033e
#
# pre_val: 33f
# post_val: 033f
#
# pre_val: 340
# post_val: 0340
#
# pre_val: 341
# post_val: 0341
#
# pre_val: 342
# post_val: 0342
#
# pre_val: 343
# post_val: 0343
#
# pre_val: 344
# post_val: 0344
#
# pre_val: 345
# post_val: 0345
#
# pre_val: 346
# post_val: 0346
#
# pre_val: 347
# post_val: 0347
#
# pre_val: 348
# post_val: 0348
#
# pre_val: 349
# post_val: 0349
#
# pre_val: 34a
# post_val: 034a
#
# pre_val: 34b
# post_val: 034b
#
# pre_val: 34c
# post_val: 034c
#
# pre_val: 34d
# post_val: 034d
#
# pre_val: 34e
# post_val: 034e
#
# pre_val: 34f
# post_val: 034f
#
# pre_val: 350
# post_val: 0350
#
# pre_val: 351
# post_val: 0351
#
# pre_val: 352
# post_val: 0352
#
# pre_val: 353
# post_val: 0353
#
# pre_val: 354
# post_val: 0354
#
# pre_val: 355
# post_val: 0355
#
# pre_val: 356
# post_val: 0356
#
# pre_val: 357
# post_val: 0357
#
# pre_val: 358
# post_val: 0358
#
# pre_val: 359
# post_val: 0359
#
# pre_val: 35a
# post_val: 035a
#
# pre_val: 35b
# post_val: 035b
#
# pre_val: 35c
# post_val: 035c
#
# pre_val: 35d
# post_val: 035d
#
# pre_val: 35e
# post_val: 035e
#
# pre_val: 35f
# post_val: 035f
#
# pre_val: 360
# post_val: 0360
#
# pre_val: 361
# post_val: 0361
#
# pre_val: 362
# post_val: 0362
#
# pre_val: 363
# post_val: 0363
#
# pre_val: 364
# post_val: 0364
#
# pre_val: 365
# post_val: 0365
#
# pre_val: 366
# post_val: 0366
#
# pre_val: 367
# post_val: 0367
#
# pre_val: 368
# post_val: 0368
#
# pre_val: 369
# post_val: 0369
#
# pre_val: 36a
# post_val: 036a
#
# pre_val: 36b
# post_val: 036b
#
# pre_val: 36c
# post_val: 036c
#
# pre_val: 36d
# post_val: 036d
#
# pre_val: 36e
# post_val: 036e
#
# pre_val: 36f
# post_val: 036f
#
# pre_val: 370
# post_val: 0370
#
# pre_val: 371
# post_val: 0371
#
# pre_val: 372
# post_val: 0372
#
# pre_val: 373
# post_val: 0373
#
# pre_val: 374
# post_val: 0374
#
# pre_val: 375
# post_val: 0375
#
# pre_val: 376
# post_val: 0376
#
# pre_val: 377
# post_val: 0377
#
# pre_val: 378
# post_val: 0378
#
# pre_val: 379
# post_val: 0379
#
# pre_val: 37a
# post_val: 037a
#
# pre_val: 37b
# post_val: 037b
#
# pre_val: 37c
# post_val: 037c
#
# pre_val: 37d
# post_val: 037d
#
# pre_val: 37e
# post_val: 037e
#
# pre_val: 37f
# post_val: 037f
#
# pre_val: 380
# post_val: 0380
#
# pre_val: 381
# post_val: 0381
#
# pre_val: 382
# post_val: 0382
#
# pre_val: 383
# post_val: 0383
#
# pre_val: 384
# post_val: 0384
#
# pre_val: 385
# post_val: 0385
#
# pre_val: 386
# post_val: 0386
#
# pre_val: 387
# post_val: 0387
#
# pre_val: 388
# post_val: 0388
#
# pre_val: 389
# post_val: 0389
#
# pre_val: 38a
# post_val: 038a
#
# pre_val: 38b
# post_val: 038b
#
# pre_val: 38c
# post_val: 038c
#
# pre_val: 38d
# post_val: 038d
#
# pre_val: 38e
# post_val: 038e
#
# pre_val: 38f
# post_val: 038f
#
# pre_val: 390
# post_val: 0390
#
# pre_val: 391
# post_val: 0391
#
# pre_val: 392
# post_val: 0392
#
# pre_val: 393
# post_val: 0393
#
# pre_val: 394
# post_val: 0394
#
# pre_val: 395
# post_val: 0395
#
# pre_val: 396
# post_val: 0396
#
# pre_val: 397
# post_val: 0397
#
# pre_val: 398
# post_val: 0398
#
# pre_val: 399
# post_val: 0399
#
# pre_val: 39a
# post_val: 039a
#
# pre_val: 39b
# post_val: 039b
#
# pre_val: 39c
# post_val: 039c
#
# pre_val: 39d
# post_val: 039d
#
# pre_val: 39e
# post_val: 039e
#
# pre_val: 39f
# post_val: 039f
#
# pre_val: 3a0
# post_val: 03a0
#
# pre_val: 3a1
# post_val: 03a1
#
# pre_val: 3a2
# post_val: 03a2
#
# pre_val: 3a3
# post_val: 03a3
#
# pre_val: 3a4
# post_val: 03a4
#
# pre_val: 3a5
# post_val: 03a5
#
# pre_val: 3a6
# post_val: 03a6
#
# pre_val: 3a7
# post_val: 03a7
#
# pre_val: 3a8
# post_val: 03a8
#
# pre_val: 3a9
# post_val: 03a9
#
# pre_val: 3aa
# post_val: 03aa
#
# pre_val: 3ab
# post_val: 03ab
#
# pre_val: 3ac
# post_val: 03ac
#
# pre_val: 3ad
# post_val: 03ad
#
# pre_val: 3ae
# post_val: 03ae
#
# pre_val: 3af
# post_val: 03af
#
# pre_val: 3b0
# post_val: 03b0
#
# pre_val: 3b1
# post_val: 03b1
#
# pre_val: 3b2
# post_val: 03b2
#
# pre_val: 3b3
# post_val: 03b3
#
# pre_val: 3b4
# post_val: 03b4
#
# pre_val: 3b5
# post_val: 03b5
#
# pre_val: 3b6
# post_val: 03b6
#
# pre_val: 3b7
# post_val: 03b7
#
# pre_val: 3b8
# post_val: 03b8
#
# pre_val: 3b9
# post_val: 03b9
#
# pre_val: 3ba
# post_val: 03ba
#
# pre_val: 3bb
# post_val: 03bb
#
# pre_val: 3bc
# post_val: 03bc
#
# pre_val: 3bd
# post_val: 03bd
#
# pre_val: 3be
# post_val: 03be
#
# pre_val: 3bf
# post_val: 03bf
#
# pre_val: 3c0
# post_val: 03c0
#
# pre_val: 3c1
# post_val: 03c1
#
# pre_val: 3c2
# post_val: 03c2
#
# pre_val: 3c3
# post_val: 03c3
#
# pre_val: 3c4
# post_val: 03c4
#
# pre_val: 3c5
# post_val: 03c5
#
# pre_val: 3c6
# post_val: 03c6
#
# pre_val: 3c7
# post_val: 03c7
#
# pre_val: 3c8
# post_val: 03c8
#
# pre_val: 3c9
# post_val: 03c9
#
# pre_val: 3ca
# post_val: 03ca
#
# pre_val: 3cb
# post_val: 03cb
#
# pre_val: 3cc
# post_val: 03cc
#
# pre_val: 3cd
# post_val: 03cd
#
# pre_val: 3ce
# post_val: 03ce
#
# pre_val: 3cf
# post_val: 03cf
#
# pre_val: 3d0
# post_val: 03d0
#
# pre_val: 3d1
# post_val: 03d1
#
# pre_val: 3d2
# post_val: 03d2
#
# pre_val: 3d3
# post_val: 03d3
#
# pre_val: 3d4
# post_val: 03d4
#
# pre_val: 3d5
# post_val: 03d5
#
# pre_val: 3d6
# post_val: 03d6
#
# pre_val: 3d7
# post_val: 03d7
#
# pre_val: 3d8
# post_val: 03d8
#
# pre_val: 3d9
# post_val: 03d9
#
# pre_val: 3da
# post_val: 03da
#
# pre_val: 3db
# post_val: 03db
#
# pre_val: 3dc
# post_val: 03dc
#
# pre_val: 3dd
# post_val: 03dd
#
# pre_val: 3de
# post_val: 03de
#
# pre_val: 3df
# post_val: 03df
#
# pre_val: 3e0
# post_val: 03e0
#
# pre_val: 3e1
# post_val: 03e1
#
# pre_val: 3e2
# post_val: 03e2
#
# pre_val: 3e3
# post_val: 03e3
#
# pre_val: 3e4
# post_val: 03e4
#
# pre_val: 3e5
# post_val: 03e5
#
# pre_val: 3e6
# post_val: 03e6
#
# pre_val: 3e7
# post_val: 03e7
#
# pre_val: 3e8
# post_val: 03e8
#
# pre_val: 3e9
# post_val: 03e9
#
# pre_val: 3ea
# post_val: 03ea
#
# pre_val: 3eb
# post_val: 03eb
#
# pre_val: 3ec
# post_val: 03ec
#
# pre_val: 3ed
# post_val: 03ed
#
# pre_val: 3ee
# post_val: 03ee
#
# pre_val: 3ef
# post_val: 03ef
#
# pre_val: 3f0
# post_val: 03f0
#
# pre_val: 3f1
# post_val: 03f1
#
# pre_val: 3f2
# post_val: 03f2
#
# pre_val: 3f3
# post_val: 03f3
#
# pre_val: 3f4
# post_val: 03f4
#
# pre_val: 3f5
# post_val: 03f5
#
# pre_val: 3f6
# post_val: 03f6
#
# pre_val: 3f7
# post_val: 03f7
#
# pre_val: 3f8
# post_val: 03f8
#
# pre_val: 3f9
# post_val: 03f9
#
# pre_val: 3fa
# post_val: 03fa
#
# pre_val: 3fb
# post_val: 03fb
#
# pre_val: 3fc
# post_val: 03fc
#
# pre_val: 3fd
# post_val: 03fd
#
# pre_val: 3fe
# post_val: 03fe
#
# pre_val: 3ff
# post_val: 03ff
#
# pre_val: 400
# post_val: 0400
#
# pre_val: 401
# post_val: 0401
#
# pre_val: 402
# post_val: 0402
#
# pre_val: 403
# post_val: 0403
#
# pre_val: 404
# post_val: 0404
#
# pre_val: 405
# post_val: 0405
#
# pre_val: 406
# post_val: 0406
#
# pre_val: 407
# post_val: 0407
#
# pre_val: 408
# post_val: 0408
#
# pre_val: 409
# post_val: 0409
#
# pre_val: 40a
# post_val: 040a
#
# pre_val: 40b
# post_val: 040b
#
# pre_val: 40c
# post_val: 040c
#
# pre_val: 40d
# post_val: 040d
#
# pre_val: 40e
# post_val: 040e
#
# pre_val: 40f
# post_val: 040f
#
# pre_val: 410
# post_val: 0410
#
# pre_val: 411
# post_val: 0411
#
# pre_val: 412
# post_val: 0412
#
# pre_val: 413
# post_val: 0413
#
# pre_val: 414
# post_val: 0414
#
# pre_val: 415
# post_val: 0415
#
# pre_val: 416
# post_val: 0416
#
# pre_val: 417
# post_val: 0417
#
# pre_val: 418
# post_val: 0418
#
# pre_val: 419
# post_val: 0419
#
# pre_val: 41a
# post_val: 041a
#
# pre_val: 41b
# post_val: 041b
#
# pre_val: 41c
# post_val: 041c
#
# pre_val: 41d
# post_val: 041d
#
# pre_val: 41e
# post_val: 041e
#
# pre_val: 41f
# post_val: 041f
#
# pre_val: 420
# post_val: 0420
#
# pre_val: 421
# post_val: 0421
#
# pre_val: 422
# post_val: 0422
#
# pre_val: 423
# post_val: 0423
#
# pre_val: 424
# post_val: 0424
#
# pre_val: 425
# post_val: 0425
#
# pre_val: 426
# post_val: 0426
#
# pre_val: 427
# post_val: 0427
#
# pre_val: 428
# post_val: 0428
#
# pre_val: 429
# post_val: 0429
#
# pre_val: 42a
# post_val: 042a
#
# pre_val: 42b
# post_val: 042b
#
# pre_val: 42c
# post_val: 042c
#
# pre_val: 42d
# post_val: 042d
#
# pre_val: 42e
# post_val: 042e
#
# pre_val: 42f
# post_val: 042f
#
# pre_val: 430
# post_val: 0430
#
# pre_val: 431
# post_val: 0431
#
# pre_val: 432
# post_val: 0432
#
# pre_val: 433
# post_val: 0433
#
# pre_val: 434
# post_val: 0434
#
# pre_val: 435
# post_val: 0435
#
# pre_val: 436
# post_val: 0436
#
# pre_val: 437
# post_val: 0437
#
# pre_val: 438
# post_val: 0438
#
# pre_val: 439
# post_val: 0439
#
# pre_val: 43a
# post_val: 043a
#
# pre_val: 43b
# post_val: 043b
#
# pre_val: 43c
# post_val: 043c
#
# pre_val: 43d
# post_val: 043d
#
# pre_val: 43e
# post_val: 043e
#
# pre_val: 43f
# post_val: 043f
#
# pre_val: 440
# post_val: 0440
#
# pre_val: 441
# post_val: 0441
#
# pre_val: 442
# post_val: 0442
#
# pre_val: 443
# post_val: 0443
#
# pre_val: 444
# post_val: 0444
#
# pre_val: 445
# post_val: 0445
#
# pre_val: 446
# post_val: 0446
#
# pre_val: 447
# post_val: 0447
#
# pre_val: 448
# post_val: 0448
#
# pre_val: 449
# post_val: 0449
#
# pre_val: 44a
# post_val: 044a
#
# pre_val: 44b
# post_val: 044b
#
# pre_val: 44c
# post_val: 044c
#
# pre_val: 44d
# post_val: 044d
#
# pre_val: 44e
# post_val: 044e
#
# pre_val: 44f
# post_val: 044f
#
# pre_val: 450
# post_val: 0450
#
# pre_val: 451
# post_val: 0451
#
# pre_val: 452
# post_val: 0452
#
# pre_val: 453
# post_val: 0453
#
# pre_val: 454
# post_val: 0454
#
# pre_val: 455
# post_val: 0455
#
# pre_val: 456
# post_val: 0456
#
# pre_val: 457
# post_val: 0457
#
# pre_val: 458
# post_val: 0458
#
# pre_val: 459
# post_val: 0459
#
# pre_val: 45a
# post_val: 045a
#
# pre_val: 45b
# post_val: 045b
#
# pre_val: 45c
# post_val: 045c
#
# pre_val: 45d
# post_val: 045d
#
# pre_val: 45e
# post_val: 045e
#
# pre_val: 45f
# post_val: 045f
#
# pre_val: 460
# post_val: 0460
#
# pre_val: 461
# post_val: 0461
#
# pre_val: 462
# post_val: 0462
#
# pre_val: 463
# post_val: 0463
#
# pre_val: 464
# post_val: 0464
#
# pre_val: 465
# post_val: 0465
#
# pre_val: 466
# post_val: 0466
#
# pre_val: 467
# post_val: 0467
#
# pre_val: 468
# post_val: 0468
#
# pre_val: 469
# post_val: 0469
#
# pre_val: 46a
# post_val: 046a
#
# pre_val: 46b
# post_val: 046b
#
# pre_val: 46c
# post_val: 046c
#
# pre_val: 46d
# post_val: 046d
#
# pre_val: 46e
# post_val: 046e
#
# pre_val: 46f
# post_val: 046f
#
# pre_val: 470
# post_val: 0470
#
# pre_val: 471
# post_val: 0471
#
# pre_val: 472
# post_val: 0472
#
# pre_val: 473
# post_val: 0473
#
# pre_val: 474
# post_val: 0474
#
# pre_val: 475
# post_val: 0475
#
# pre_val: 476
# post_val: 0476
#
# pre_val: 477
# post_val: 0477
#
# pre_val: 478
# post_val: 0478
#
# pre_val: 479
# post_val: 0479
#
# pre_val: 47a
# post_val: 047a
#
# pre_val: 47b
# post_val: 047b
#
# pre_val: 47c
# post_val: 047c
#
# pre_val: 47d
# post_val: 047d
#
# pre_val: 47e
# post_val: 047e
#
# pre_val: 47f
# post_val: 047f
#
# pre_val: 480
# post_val: 0480
#
# pre_val: 481
# post_val: 0481
#
# pre_val: 482
# post_val: 0482
#
# pre_val: 483
# post_val: 0483
#
# pre_val: 484
# post_val: 0484
#
# pre_val: 485
# post_val: 0485
#
# pre_val: 486
# post_val: 0486
#
# pre_val: 487
# post_val: 0487
#
# pre_val: 488
# post_val: 0488
#
# pre_val: 489
# post_val: 0489
#
# pre_val: 48a
# post_val: 048a
#
# pre_val: 48b
# post_val: 048b
#
# pre_val: 48c
# post_val: 048c
#
# pre_val: 48d
# post_val: 048d
#
# pre_val: 48e
# post_val: 048e
#
# pre_val: 48f
# post_val: 048f
#
# pre_val: 490
# post_val: 0490
#
# pre_val: 491
# post_val: 0491
#
# pre_val: 492
# post_val: 0492
#
# pre_val: 493
# post_val: 0493
#
# pre_val: 494
# post_val: 0494
#
# pre_val: 495
# post_val: 0495
#
# pre_val: 496
# post_val: 0496
#
# pre_val: 497
# post_val: 0497
#
# pre_val: 498
# post_val: 0498
#
# pre_val: 499
# post_val: 0499
#
# pre_val: 49a
# post_val: 049a
#
# pre_val: 49b
# post_val: 049b
#
# pre_val: 49c
# post_val: 049c
#
# pre_val: 49d
# post_val: 049d
#
# pre_val: 49e
# post_val: 049e
#
# pre_val: 49f
# post_val: 049f
#
# pre_val: 4a0
# post_val: 04a0
#
# pre_val: 4a1
# post_val: 04a1
#
# pre_val: 4a2
# post_val: 04a2
#
# pre_val: 4a3
# post_val: 04a3
#
# pre_val: 4a4
# post_val: 04a4
#
# pre_val: 4a5
# post_val: 04a5
#
# pre_val: 4a6
# post_val: 04a6
#
# pre_val: 4a7
# post_val: 04a7
#
# pre_val: 4a8
# post_val: 04a8
#
# pre_val: 4a9
# post_val: 04a9
#
# pre_val: 4aa
# post_val: 04aa
#
# pre_val: 4ab
# post_val: 04ab
#
# pre_val: 4ac
# post_val: 04ac
#
# pre_val: 4ad
# post_val: 04ad
#
# pre_val: 4ae
# post_val: 04ae
#
# pre_val: 4af
# post_val: 04af
#
# pre_val: 4b0
# post_val: 04b0
#
# pre_val: 4b1
# post_val: 04b1
#
# pre_val: 4b2
# post_val: 04b2
#
# pre_val: 4b3
# post_val: 04b3
#
# pre_val: 4b4
# post_val: 04b4
#
# pre_val: 4b5
# post_val: 04b5
#
# pre_val: 4b6
# post_val: 04b6
#
# pre_val: 4b7
# post_val: 04b7
#
# pre_val: 4b8
# post_val: 04b8
#
# pre_val: 4b9
# post_val: 04b9
#
# pre_val: 4ba
# post_val: 04ba
#
# pre_val: 4bb
# post_val: 04bb
#
# pre_val: 4bc
# post_val: 04bc
#
# pre_val: 4bd
# post_val: 04bd
#
# pre_val: 4be
# post_val: 04be
#
# pre_val: 4bf
# post_val: 04bf
#
# pre_val: 4c0
# post_val: 04c0
#
# pre_val: 4c1
# post_val: 04c1
#
# pre_val: 4c2
# post_val: 04c2
#
# pre_val: 4c3
# post_val: 04c3
#
# pre_val: 4c4
# post_val: 04c4
#
# pre_val: 4c5
# post_val: 04c5
#
# pre_val: 4c6
# post_val: 04c6
#
# pre_val: 4c7
# post_val: 04c7
#
# pre_val: 4c8
# post_val: 04c8
#
# pre_val: 4c9
# post_val: 04c9
#
# pre_val: 4ca
# post_val: 04ca
#
# pre_val: 4cb
# post_val: 04cb
#
# pre_val: 4cc
# post_val: 04cc
#
# pre_val: 4cd
# post_val: 04cd
#
# pre_val: 4ce
# post_val: 04ce
#
# pre_val: 4cf
# post_val: 04cf
#
# pre_val: 4d0
# post_val: 04d0
#
# pre_val: 4d1
# post_val: 04d1
#
# pre_val: 4d2
# post_val: 04d2
#
# pre_val: 4d3
# post_val: 04d3
#
# pre_val: 4d4
# post_val: 04d4
#
# pre_val: 4d5
# post_val: 04d5
#
# pre_val: 4d6
# post_val: 04d6
#
# pre_val: 4d7
# post_val: 04d7
#
# pre_val: 4d8
# post_val: 04d8
#
# pre_val: 4d9
# post_val: 04d9
#
# pre_val: 4da
# post_val: 04da
#
# pre_val: 4db
# post_val: 04db
#
# pre_val: 4dc
# post_val: 04dc
#
# pre_val: 4dd
# post_val: 04dd
#
# pre_val: 4de
# post_val: 04de
#
# pre_val: 4df
# post_val: 04df
#
# pre_val: 4e0
# post_val: 04e0
#
# pre_val: 4e1
# post_val: 04e1
#
# pre_val: 4e2
# post_val: 04e2
#
# pre_val: 4e3
# post_val: 04e3
#
# pre_val: 4e4
# post_val: 04e4
#
# pre_val: 4e5
# post_val: 04e5
#
# pre_val: 4e6
# post_val: 04e6
#
# pre_val: 4e7
# post_val: 04e7
#
# pre_val: 4e8
# post_val: 04e8
#
# pre_val: 4e9
# post_val: 04e9
#
# pre_val: 4ea
# post_val: 04ea
#
# pre_val: 4eb
# post_val: 04eb
#
# pre_val: 4ec
# post_val: 04ec
#
# pre_val: 4ed
# post_val: 04ed
#
# pre_val: 4ee
# post_val: 04ee
#
# pre_val: 4ef
# post_val: 04ef
#
# pre_val: 4f0
# post_val: 04f0
#
# pre_val: 4f1
# post_val: 04f1
#
# pre_val: 4f2
# post_val: 04f2
#
# pre_val: 4f3
# post_val: 04f3
#
# pre_val: 4f4
# post_val: 04f4
#
# pre_val: 4f5
# post_val: 04f5
#
# pre_val: 4f6
# post_val: 04f6
#
# pre_val: 4f7
# post_val: 04f7
#
# pre_val: 4f8
# post_val: 04f8
#
# pre_val: 4f9
# post_val: 04f9
#
# pre_val: 4fa
# post_val: 04fa
#
# pre_val: 4fb
# post_val: 04fb
#
# pre_val: 4fc
# post_val: 04fc
#
# pre_val: 4fd
# post_val: 04fd
#
# pre_val: 4fe
# post_val: 04fe
#
# pre_val: 4ff
# post_val: 04ff
#
# pre_val: 500
# post_val: 0500
#
# pre_val: 501
# post_val: 0501
#
# pre_val: 502
# post_val: 0502
#
# pre_val: 503
# post_val: 0503
#
# pre_val: 504
# post_val: 0504
#
# pre_val: 505
# post_val: 0505
#
# pre_val: 506
# post_val: 0506
#
# pre_val: 507
# post_val: 0507
#
# pre_val: 508
# post_val: 0508
#
# pre_val: 509
# post_val: 0509
#
# pre_val: 50a
# post_val: 050a
#
# pre_val: 50b
# post_val: 050b
#
# pre_val: 50c
# post_val: 050c
#
# pre_val: 50d
# post_val: 050d
#
# pre_val: 50e
# post_val: 050e
#
# pre_val: 50f
# post_val: 050f
#
# pre_val: 510
# post_val: 0510
#
# pre_val: 511
# post_val: 0511
#
# pre_val: 512
# post_val: 0512
#
# pre_val: 513
# post_val: 0513
#
# pre_val: 514
# post_val: 0514
#
# pre_val: 515
# post_val: 0515
#
# pre_val: 516
# post_val: 0516
#
# pre_val: 517
# post_val: 0517
#
# pre_val: 518
# post_val: 0518
#
# pre_val: 519
# post_val: 0519
#
# pre_val: 51a
# post_val: 051a
#
# pre_val: 51b
# post_val: 051b
#
# pre_val: 51c
# post_val: 051c
#
# pre_val: 51d
# post_val: 051d
#
# pre_val: 51e
# post_val: 051e
#
# pre_val: 51f
# post_val: 051f
#
# pre_val: 520
# post_val: 0520
#
# pre_val: 521
# post_val: 0521
#
# pre_val: 522
# post_val: 0522
#
# pre_val: 523
# post_val: 0523
#
# pre_val: 524
# post_val: 0524
#
# pre_val: 525
# post_val: 0525
#
# pre_val: 526
# post_val: 0526
#
# pre_val: 527
# post_val: 0527
#
# pre_val: 528
# post_val: 0528
#
# pre_val: 529
# post_val: 0529
#
# pre_val: 52a
# post_val: 052a
#
# pre_val: 52b
# post_val: 052b
#
# pre_val: 52c
# post_val: 052c
#
# pre_val: 52d
# post_val: 052d
#
# pre_val: 52e
# post_val: 052e
#
# pre_val: 52f
# post_val: 052f
#
# pre_val: 530
# post_val: 0530
#
# pre_val: 531
# post_val: 0531
#
# pre_val: 532
# post_val: 0532
#
# pre_val: 533
# post_val: 0533
#
# pre_val: 534
# post_val: 0534
#
# pre_val: 535
# post_val: 0535
#
# pre_val: 536
# post_val: 0536
#
# pre_val: 537
# post_val: 0537
#
# pre_val: 538
# post_val: 0538
#
# pre_val: 539
# post_val: 0539
#
# pre_val: 53a
# post_val: 053a
#
# pre_val: 53b
# post_val: 053b
#
# pre_val: 53c
# post_val: 053c
#
# pre_val: 53d
# post_val: 053d
#
# pre_val: 53e
# post_val: 053e
#
# pre_val: 53f
# post_val: 053f
#
# pre_val: 540
# post_val: 0540
#
# pre_val: 541
# post_val: 0541
#
# pre_val: 542
# post_val: 0542
#
# pre_val: 543
# post_val: 0543
#
# pre_val: 544
# post_val: 0544
#
# pre_val: 545
# post_val: 0545
#
# pre_val: 546
# post_val: 0546
#
# pre_val: 547
# post_val: 0547
#
# pre_val: 548
# post_val: 0548
#
# pre_val: 549
# post_val: 0549
#
# pre_val: 54a
# post_val: 054a
#
# pre_val: 54b
# post_val: 054b
#
# pre_val: 54c
# post_val: 054c
#
# pre_val: 54d
# post_val: 054d
#
# pre_val: 54e
# post_val: 054e
#
# pre_val: 54f
# post_val: 054f
#
# pre_val: 550
# post_val: 0550
#
# pre_val: 551
# post_val: 0551
#
# pre_val: 552
# post_val: 0552
#
# pre_val: 553
# post_val: 0553
#
# pre_val: 554
# post_val: 0554
#
# pre_val: 555
# post_val: 0555
#
# pre_val: 556
# post_val: 0556
#
# pre_val: 557
# post_val: 0557
#
# pre_val: 558
# post_val: 0558
#
# pre_val: 559
# post_val: 0559
#
# pre_val: 55a
# post_val: 055a
#
# pre_val: 55b
# post_val: 055b
#
# pre_val: 55c
# post_val: 055c
#
# pre_val: 55d
# post_val: 055d
#
# pre_val: 55e
# post_val: 055e
#
# pre_val: 55f
# post_val: 055f
#
# pre_val: 560
# post_val: 0560
#
# pre_val: 561
# post_val: 0561
#
# pre_val: 562
# post_val: 0562
#
# pre_val: 563
# post_val: 0563
#
# pre_val: 564
# post_val: 0564
#
# pre_val: 565
# post_val: 0565
#
# pre_val: 566
# post_val: 0566
#
# pre_val: 567
# post_val: 0567
#
# pre_val: 568
# post_val: 0568
#
# pre_val: 569
# post_val: 0569
#
# pre_val: 56a
# post_val: 056a
#
# pre_val: 56b
# post_val: 056b
#
# pre_val: 56c
# post_val: 056c
#
# pre_val: 56d
# post_val: 056d
#
# pre_val: 56e
# post_val: 056e
#
# pre_val: 56f
# post_val: 056f
#
# pre_val: 570
# post_val: 0570
#
# pre_val: 571
# post_val: 0571
#
# pre_val: 572
# post_val: 0572
#
# pre_val: 573
# post_val: 0573
#
# pre_val: 574
# post_val: 0574
#
# pre_val: 575
# post_val: 0575
#
# pre_val: 576
# post_val: 0576
#
# pre_val: 577
# post_val: 0577
#
# pre_val: 578
# post_val: 0578
#
# pre_val: 579
# post_val: 0579
#
# pre_val: 57a
# post_val: 057a
#
# pre_val: 57b
# post_val: 057b
#
# pre_val: 57c
# post_val: 057c
#
# pre_val: 57d
# post_val: 057d
#
# pre_val: 57e
# post_val: 057e
#
# pre_val: 57f
# post_val: 057f
#
# pre_val: 580
# post_val: 0580
#
# pre_val: 581
# post_val: 0581
#
# pre_val: 582
# post_val: 0582
#
# pre_val: 583
# post_val: 0583
#
# pre_val: 584
# post_val: 0584
#
# pre_val: 585
# post_val: 0585
#
# pre_val: 586
# post_val: 0586
#
# pre_val: 587
# post_val: 0587
#
# pre_val: 588
# post_val: 0588
#
# pre_val: 589
# post_val: 0589
#
# pre_val: 58a
# post_val: 058a
#
# pre_val: 58b
# post_val: 058b
#
# pre_val: 58c
# post_val: 058c
#
# pre_val: 58d
# post_val: 058d
#
# pre_val: 58e
# post_val: 058e
#
# pre_val: 58f
# post_val: 058f
#
# pre_val: 590
# post_val: 0590
#
# pre_val: 591
# post_val: 0591
#
# pre_val: 592
# post_val: 0592
#
# pre_val: 593
# post_val: 0593
#
# pre_val: 594
# post_val: 0594
#
# pre_val: 595
# post_val: 0595
#
# pre_val: 596
# post_val: 0596
#
# pre_val: 597
# post_val: 0597
#
# pre_val: 598
# post_val: 0598
#
# pre_val: 599
# post_val: 0599
#
# pre_val: 59a
# post_val: 059a
#
# pre_val: 59b
# post_val: 059b
#
# pre_val: 59c
# post_val: 059c
#
# pre_val: 59d
# post_val: 059d
#
# pre_val: 59e
# post_val: 059e
#
# pre_val: 59f
# post_val: 059f
#
# pre_val: 5a0
# post_val: 05a0
#
# pre_val: 5a1
# post_val: 05a1
#
# pre_val: 5a2
# post_val: 05a2
#
# pre_val: 5a3
# post_val: 05a3
#
# pre_val: 5a4
# post_val: 05a4
#
# pre_val: 5a5
# post_val: 05a5
#
# pre_val: 5a6
# post_val: 05a6
#
# pre_val: 5a7
# post_val: 05a7
#
# pre_val: 5a8
# post_val: 05a8
#
# pre_val: 5a9
# post_val: 05a9
#
# pre_val: 5aa
# post_val: 05aa
#
# pre_val: 5ab
# post_val: 05ab
#
# pre_val: 5ac
# post_val: 05ac
#
# pre_val: 5ad
# post_val: 05ad
#
# pre_val: 5ae
# post_val: 05ae
#
# pre_val: 5af
# post_val: 05af
#
# pre_val: 5b0
# post_val: 05b0
#
# pre_val: 5b1
# post_val: 05b1
#
# pre_val: 5b2
# post_val: 05b2
#
# pre_val: 5b3
# post_val: 05b3
#
# pre_val: 5b4
# post_val: 05b4
#
# pre_val: 5b5
# post_val: 05b5
#
# pre_val: 5b6
# post_val: 05b6
#
# pre_val: 5b7
# post_val: 05b7
#
# pre_val: 5b8
# post_val: 05b8
#
# pre_val: 5b9
# post_val: 05b9
#
# pre_val: 5ba
# post_val: 05ba
#
# pre_val: 5bb
# post_val: 05bb
#
# pre_val: 5bc
# post_val: 05bc
#
# pre_val: 5bd
# post_val: 05bd
#
# pre_val: 5be
# post_val: 05be
#
# pre_val: 5bf
# post_val: 05bf
#
# pre_val: 5c0
# post_val: 05c0
#
# pre_val: 5c1
# post_val: 05c1
#
# pre_val: 5c2
# post_val: 05c2
#
# pre_val: 5c3
# post_val: 05c3
#
# pre_val: 5c4
# post_val: 05c4
#
# pre_val: 5c5
# post_val: 05c5
#
# pre_val: 5c6
# post_val: 05c6
#
# pre_val: 5c7
# post_val: 05c7
#
# pre_val: 5c8
# post_val: 05c8
#
# pre_val: 5c9
# post_val: 05c9
#
# pre_val: 5ca
# post_val: 05ca
#
# pre_val: 5cb
# post_val: 05cb
#
# pre_val: 5cc
# post_val: 05cc
#
# pre_val: 5cd
# post_val: 05cd
#
# pre_val: 5ce
# post_val: 05ce
#
# pre_val: 5cf
# post_val: 05cf
#
# pre_val: 5d0
# post_val: 05d0
#
# pre_val: 5d1
# post_val: 05d1
#
# pre_val: 5d2
# post_val: 05d2
#
# pre_val: 5d3
# post_val: 05d3
#
# pre_val: 5d4
# post_val: 05d4
#
# pre_val: 5d5
# post_val: 05d5
#
# pre_val: 5d6
# post_val: 05d6
#
# pre_val: 5d7
# post_val: 05d7
#
# pre_val: 5d8
# post_val: 05d8
#
# pre_val: 5d9
# post_val: 05d9
#
# pre_val: 5da
# post_val: 05da
#
# pre_val: 5db
# post_val: 05db
#
# pre_val: 5dc
# post_val: 05dc
#
# pre_val: 5dd
# post_val: 05dd
#
# pre_val: 5de
# post_val: 05de
#
# pre_val: 5df
# post_val: 05df
#
# pre_val: 5e0
# post_val: 05e0
#
# pre_val: 5e1
# post_val: 05e1
#
# pre_val: 5e2
# post_val: 05e2
#
# pre_val: 5e3
# post_val: 05e3
#
# pre_val: 5e4
# post_val: 05e4
#
# pre_val: 5e5
# post_val: 05e5
#
# pre_val: 5e6
# post_val: 05e6
#
# pre_val: 5e7
# post_val: 05e7
#
# pre_val: 5e8
# post_val: 05e8
#
# pre_val: 5e9
# post_val: 05e9
#
# pre_val: 5ea
# post_val: 05ea
#
# pre_val: 5eb
# post_val: 05eb
#
# pre_val: 5ec
# post_val: 05ec
#
# pre_val: 5ed
# post_val: 05ed
#
# pre_val: 5ee
# post_val: 05ee
#
# pre_val: 5ef
# post_val: 05ef
#
# pre_val: 5f0
# post_val: 05f0
#
# pre_val: 5f1
# post_val: 05f1
#
# pre_val: 5f2
# post_val: 05f2
#
# pre_val: 5f3
# post_val: 05f3
#
# pre_val: 5f4
# post_val: 05f4
#
# pre_val: 5f5
# post_val: 05f5
#
# pre_val: 5f6
# post_val: 05f6
#
# pre_val: 5f7
# post_val: 05f7
#
# pre_val: 5f8
# post_val: 05f8
#
# pre_val: 5f9
# post_val: 05f9
#
# pre_val: 5fa
# post_val: 05fa
#
# pre_val: 5fb
# post_val: 05fb
#
# pre_val: 5fc
# post_val: 05fc
#
# pre_val: 5fd
# post_val: 05fd
#
# pre_val: 5fe
# post_val: 05fe
#
# pre_val: 5ff
# post_val: 05ff
#
# pre_val: 600
# post_val: 0600
#
# pre_val: 601
# post_val: 0601
#
# pre_val: 602
# post_val: 0602
#
# pre_val: 603
# post_val: 0603
#
# pre_val: 604
# post_val: 0604
#
# pre_val: 605
# post_val: 0605
#
# pre_val: 606
# post_val: 0606
#
# pre_val: 607
# post_val: 0607
#
# pre_val: 608
# post_val: 0608
#
# pre_val: 609
# post_val: 0609
#
# pre_val: 60a
# post_val: 060a
#
# pre_val: 60b
# post_val: 060b
#
# pre_val: 60c
# post_val: 060c
#
# pre_val: 60d
# post_val: 060d
#
# pre_val: 60e
# post_val: 060e
#
# pre_val: 60f
# post_val: 060f
#
# pre_val: 610
# post_val: 0610
#
# pre_val: 611
# post_val: 0611
#
# pre_val: 612
# post_val: 0612
#
# pre_val: 613
# post_val: 0613
#
# pre_val: 614
# post_val: 0614
#
# pre_val: 615
# post_val: 0615
#
# pre_val: 616
# post_val: 0616
#
# pre_val: 617
# post_val: 0617
#
# pre_val: 618
# post_val: 0618
#
# pre_val: 619
# post_val: 0619
#
# pre_val: 61a
# post_val: 061a
#
# pre_val: 61b
# post_val: 061b
#
# pre_val: 61c
# post_val: 061c
#
# pre_val: 61d
# post_val: 061d
#
# pre_val: 61e
# post_val: 061e
#
# pre_val: 61f
# post_val: 061f
#
# pre_val: 620
# post_val: 0620
#
# pre_val: 621
# post_val: 0621
#
# pre_val: 622
# post_val: 0622
#
# pre_val: 623
# post_val: 0623
#
# pre_val: 624
# post_val: 0624
#
# pre_val: 625
# post_val: 0625
#
# pre_val: 626
# post_val: 0626
#
# pre_val: 627
# post_val: 0627
#
# pre_val: 628
# post_val: 0628
#
# pre_val: 629
# post_val: 0629
#
# pre_val: 62a
# post_val: 062a
#
# pre_val: 62b
# post_val: 062b
#
# pre_val: 62c
# post_val: 062c
#
# pre_val: 62d
# post_val: 062d
#
# pre_val: 62e
# post_val: 062e
#
# pre_val: 62f
# post_val: 062f
#
# pre_val: 630
# post_val: 0630
#
# pre_val: 631
# post_val: 0631
#
# pre_val: 632
# post_val: 0632
#
# pre_val: 633
# post_val: 0633
#
# pre_val: 634
# post_val: 0634
#
# pre_val: 635
# post_val: 0635
#
# pre_val: 636
# post_val: 0636
#
# pre_val: 637
# post_val: 0637
#
# pre_val: 638
# post_val: 0638
#
# pre_val: 639
# post_val: 0639
#
# pre_val: 63a
# post_val: 063a
#
# pre_val: 63b
# post_val: 063b
#
# pre_val: 63c
# post_val: 063c
#
# pre_val: 63d
# post_val: 063d
#
# pre_val: 63e
# post_val: 063e
#
# pre_val: 63f
# post_val: 063f
#
# pre_val: 640
# post_val: 0640
#
# pre_val: 641
# post_val: 0641
#
# pre_val: 642
# post_val: 0642
#
# pre_val: 643
# post_val: 0643
#
# pre_val: 644
# post_val: 0644
#
# pre_val: 645
# post_val: 0645
#
# pre_val: 646
# post_val: 0646
#
# pre_val: 647
# post_val: 0647
#
# pre_val: 648
# post_val: 0648
#
# pre_val: 649
# post_val: 0649
#
# pre_val: 64a
# post_val: 064a
#
# pre_val: 64b
# post_val: 064b
#
# pre_val: 64c
# post_val: 064c
#
# pre_val: 64d
# post_val: 064d
#
# pre_val: 64e
# post_val: 064e
#
# pre_val: 64f
# post_val: 064f
#
# pre_val: 650
# post_val: 0650
#
# pre_val: 651
# post_val: 0651
#
# pre_val: 652
# post_val: 0652
#
# pre_val: 653
# post_val: 0653
#
# pre_val: 654
# post_val: 0654
#
# pre_val: 655
# post_val: 0655
#
# pre_val: 656
# post_val: 0656
#
# pre_val: 657
# post_val: 0657
#
# pre_val: 658
# post_val: 0658
#
# pre_val: 659
# post_val: 0659
#
# pre_val: 65a
# post_val: 065a
#
# pre_val: 65b
# post_val: 065b
#
# pre_val: 65c
# post_val: 065c
#
# pre_val: 65d
# post_val: 065d
#
# pre_val: 65e
# post_val: 065e
#
# pre_val: 65f
# post_val: 065f
#
# pre_val: 660
# post_val: 0660
#
# pre_val: 661
# post_val: 0661
#
# pre_val: 662
# post_val: 0662
#
# pre_val: 663
# post_val: 0663
#
# pre_val: 664
# post_val: 0664
#
# pre_val: 665
# post_val: 0665
#
# pre_val: 666
# post_val: 0666
#
# pre_val: 667
# post_val: 0667
#
# pre_val: 668
# post_val: 0668
#
# pre_val: 669
# post_val: 0669
#
# pre_val: 66a
# post_val: 066a
#
# pre_val: 66b
# post_val: 066b
#
# pre_val: 66c
# post_val: 066c
#
# pre_val: 66d
# post_val: 066d
#
# pre_val: 66e
# post_val: 066e
#
# pre_val: 66f
# post_val: 066f
#
# pre_val: 670
# post_val: 0670
#
# pre_val: 671
# post_val: 0671
#
# pre_val: 672
# post_val: 0672
#
# pre_val: 673
# post_val: 0673
#
# pre_val: 674
# post_val: 0674
#
# pre_val: 675
# post_val: 0675
#
# pre_val: 676
# post_val: 0676
#
# pre_val: 677
# post_val: 0677
#
# pre_val: 678
# post_val: 0678
#
# pre_val: 679
# post_val: 0679
#
# pre_val: 67a
# post_val: 067a
#
# pre_val: 67b
# post_val: 067b
#
# pre_val: 67c
# post_val: 067c
#
# pre_val: 67d
# post_val: 067d
#
# pre_val: 67e
# post_val: 067e
#
# pre_val: 67f
# post_val: 067f
#
# pre_val: 680
# ...
# pre_val: 3a0a
# pre_val: 3a0b
# pre_val: 3a0c
# pre_val: 3a0d
# pre_val: 3a0e
# pre_val: 3a0f
# pre_val: 3a10
# pre_val: 3a11
# pre_val: 3a12
# pre_val: 3a13
# pre_val: 3a14
# pre_val: 3a15
# pre_val: 3a16
# pre_val: 3a17
# pre_val: 3a18
# pre_val: 3a19
# pre_val: 3a1a
# pre_val: 3a1b
# pre_val: 3a1c
# pre_val: 3a1d
# pre_val: 3a1e
# pre_val: 3a1f
# pre_val: 3a20
# pre_val: 3a21
# pre_val: 3a22
# pre_val: 3a23
# pre_val: 3a24
# pre_val: 3a25
# pre_val: 3a26
# pre_val: 3a27
# pre_val: 3a28
# pre_val: 3a29
# pre_val: 3a2a
# pre_val: 3a2b
# pre_val: 3a2c
# pre_val: 3a2d
# pre_val: 3a2e
# pre_val: 3a2f
# pre_val: 3a30
# pre_val: 3a31
# pre_val: 3a32
# pre_val: 3a33
# pre_val: 3a34
# pre_val: 3a35
# pre_val: 3a36
# pre_val: 3a37
# pre_val: 3a38
# pre_val: 3a39
# pre_val: 3a3a
# pre_val: 3a3b
# pre_val: 3a3c
# pre_val: 3a3d
# pre_val: 3a3e
# pre_val: 3a3f
# pre_val: 3a40
# pre_val: 3a41
# pre_val: 3a42
# pre_val: 3a43
# pre_val: 3a44
# pre_val: 3a45
# pre_val: 3a46
# pre_val: 3a47
# pre_val: 3a48
# pre_val: 3a49
# pre_val: 3a4a
# pre_val: 3a4b
# pre_val: 3a4c
# pre_val: 3a4d
# pre_val: 3a4e
# pre_val: 3a4f
# pre_val: 3a50
# pre_val: 3a51
# pre_val: 3a52
# pre_val: 3a53
# pre_val: 3a54
# pre_val: 3a55
# pre_val: 3a56
# pre_val: 3a57
# pre_val: 3a58
# pre_val: 3a59
# pre_val: 3a5a
# pre_val: 3a5b
# pre_val: 3a5c
# pre_val: 3a5d
# pre_val: 3a5e
# pre_val: 3a5f
# pre_val: 3a60
# pre_val: 3a61
# pre_val: 3a62
# pre_val: 3a63
# pre_val: 3a64
# pre_val: 3a65
# pre_val: 3a66
# pre_val: 3a67
# pre_val: 3a68
# pre_val: 3a69
# pre_val: 3a6a
# pre_val: 3a6b
# pre_val: 3a6c
# pre_val: 3a6d
# pre_val: 3a6e
# pre_val: 3a6f
# pre_val: 3a70
# pre_val: 3a71
# pre_val: 3a72
# pre_val: 3a73
# pre_val: 3a74
# pre_val: 3a75
# pre_val: 3a76
# pre_val: 3a77
# pre_val: 3a78
# pre_val: 3a79
# pre_val: 3a7a
# pre_val: 3a7b
# pre_val: 3a7c
# pre_val: 3a7d
# pre_val: 3a7e
# pre_val: 3a7f
# pre_val: 3a80
# pre_val: 3a81
# pre_val: 3a82
# pre_val: 3a83
# pre_val: 3a84
# pre_val: 3a85
# pre_val: 3a86
# pre_val: 3a87
# pre_val: 3a88
# pre_val: 3a89
# pre_val: 3a8a
# pre_val: 3a8b
# pre_val: 3a8c
# pre_val: 3a8d
# pre_val: 3a8e
# pre_val: 3a8f
# pre_val: 3a90
# pre_val: 3a91
# pre_val: 3a92
# pre_val: 3a93
# pre_val: 3a94
# pre_val: 3a95
# pre_val: 3a96
# pre_val: 3a97
# pre_val: 3a98
# pre_val: 3a99
# pre_val: 3a9a
# pre_val: 3a9b
# pre_val: 3a9c
# pre_val: 3a9d
# pre_val: 3a9e
# pre_val: 3a9f
# pre_val: 3aa0
# pre_val: 3aa1
# pre_val: 3aa2
# pre_val: 3aa3
# pre_val: 3aa4
# pre_val: 3aa5
# pre_val: 3aa6
# pre_val: 3aa7
# pre_val: 3aa8
# pre_val: 3aa9
# pre_val: 3aaa
# pre_val: 3aab
# pre_val: 3aac
# pre_val: 3aad
# pre_val: 3aae
# pre_val: 3aaf
# pre_val: 3ab0
# pre_val: 3ab1
# pre_val: 3ab2
# pre_val: 3ab3
# pre_val: 3ab4
# pre_val: 3ab5
# pre_val: 3ab6
# pre_val: 3ab7
# pre_val: 3ab8
# pre_val: 3ab9
# pre_val: 3aba
# pre_val: 3abb
# pre_val: 3abc
# pre_val: 3abd
# pre_val: 3abe
# pre_val: 3abf
# pre_val: 3ac0
# pre_val: 3ac1
# pre_val: 3ac2
# pre_val: 3ac3
# pre_val: 3ac4
# pre_val: 3ac5
# pre_val: 3ac6
# pre_val: 3ac7
# pre_val: 3ac8
# pre_val: 3ac9
# pre_val: 3aca
# pre_val: 3acb
# pre_val: 3acc
# pre_val: 3acd
# pre_val: 3ace
# pre_val: 3acf
# pre_val: 3ad0
# pre_val: 3ad1
# pre_val: 3ad2
# pre_val: 3ad3
# pre_val: 3ad4
# pre_val: 3ad5
# pre_val: 3ad6
# pre_val: 3ad7
# pre_val: 3ad8
# pre_val: 3ad9
# pre_val: 3ada
# pre_val: 3adb
# pre_val: 3adc
# pre_val: 3add
# pre_val: 3ade
# pre_val: 3adf
# pre_val: 3ae0
# pre_val: 3ae1
# pre_val: 3ae2
# pre_val: 3ae3
# pre_val: 3ae4
# pre_val: 3ae5
# pre_val: 3ae6
# pre_val: 3ae7
# pre_val: 3ae8
# pre_val: 3ae9
# pre_val: 3aea
# pre_val: 3aeb
# pre_val: 3aec
# pre_val: 3aed
# pre_val: 3aee
# pre_val: 3aef
# pre_val: 3af0
# pre_val: 3af1
# pre_val: 3af2
# pre_val: 3af3
# pre_val: 3af4
# pre_val: 3af5
# pre_val: 3af6
# pre_val: 3af7
# pre_val: 3af8
# pre_val: 3af9
# pre_val: 3afa
# pre_val: 3afb
# pre_val: 3afc
# pre_val: 3afd
# pre_val: 3afe
# pre_val: 3aff
# pre_val: 3b00
# pre_val: 3b01
# pre_val: 3b02
# pre_val: 3b03
# pre_val: 3b04
# pre_val: 3b05
# pre_val: 3b06
# pre_val: 3b07
# pre_val: 3b08
# pre_val: 3b09
# pre_val: 3b0a
# pre_val: 3b0b
# pre_val: 3b0c
# pre_val: 3b0d
# pre_val: 3b0e
# pre_val: 3b0f
# pre_val: 3b10
# pre_val: 3b11
# pre_val: 3b12
# pre_val: 3b13
# pre_val: 3b14
# pre_val: 3b15
# pre_val: 3b16
# pre_val: 3b17
# pre_val: 3b18
# pre_val: 3b19
# pre_val: 3b1a
# pre_val: 3b1b
# pre_val: 3b1c
# pre_val: 3b1d
# pre_val: 3b1e
# pre_val: 3b1f
# pre_val: 3b20
# pre_val: 3b21
# pre_val: 3b22
# pre_val: 3b23
# pre_val: 3b24
# pre_val: 3b25
# pre_val: 3b26
# pre_val: 3b27
# pre_val: 3b28
# pre_val: 3b29
# pre_val: 3b2a
# pre_val: 3b2b
# pre_val: 3b2c
# pre_val: 3b2d
# pre_val: 3b2e
# pre_val: 3b2f
# pre_val: 3b30
# pre_val: 3b31
# pre_val: 3b32
# pre_val: 3b33
# pre_val: 3b34
# pre_val: 3b35
# pre_val: 3b36
# pre_val: 3b37
# pre_val: 3b38
# pre_val: 3b39
# pre_val: 3b3a
# pre_val: 3b3b
# pre_val: 3b3c
# pre_val: 3b3d
# pre_val: 3b3e
# pre_val: 3b3f
# pre_val: 3b40
# pre_val: 3b41
# pre_val: 3b42
# pre_val: 3b43
# pre_val: 3b44
# pre_val: 3b45
# pre_val: 3b46
# pre_val: 3b47
# pre_val: 3b48
# pre_val: 3b49
# pre_val: 3b4a
# pre_val: 3b4b
# pre_val: 3b4c
# pre_val: 3b4d
# pre_val: 3b4e
# pre_val: 3b4f
# pre_val: 3b50
# pre_val: 3b51
# pre_val: 3b52
# pre_val: 3b53
# pre_val: 3b54
# pre_val: 3b55
# pre_val: 3b56
# pre_val: 3b57
# pre_val: 3b58
# pre_val: 3b59
# pre_val: 3b5a
# pre_val: 3b5b
# pre_val: 3b5c
# pre_val: 3b5d
# pre_val: 3b5e
# pre_val: 3b5f
# pre_val: 3b60
# pre_val: 3b61
# pre_val: 3b62
# pre_val: 3b63
# pre_val: 3b64
# pre_val: 3b65
# pre_val: 3b66
# pre_val: 3b67
# pre_val: 3b68
# pre_val: 3b69
# pre_val: 3b6a
# pre_val: 3b6b
# pre_val: 3b6c
# pre_val: 3b6d
# pre_val: 3b6e
# pre_val: 3b6f
# pre_val: 3b70
# pre_val: 3b71
# pre_val: 3b72
# pre_val: 3b73
# pre_val: 3b74
# pre_val: 3b75
# pre_val: 3b76
# pre_val: 3b77
# pre_val: 3b78
# pre_val: 3b79
# pre_val: 3b7a
# pre_val: 3b7b
# pre_val: 3b7c
# pre_val: 3b7d
# pre_val: 3b7e
# pre_val: 3b7f
# pre_val: 3b80
# pre_val: 3b81
# pre_val: 3b82
# pre_val: 3b83
# pre_val: 3b84
# pre_val: 3b85
# pre_val: 3b86
# pre_val: 3b87
# pre_val: 3b88
# pre_val: 3b89
# pre_val: 3b8a
# pre_val: 3b8b
# pre_val: 3b8c
# pre_val: 3b8d
# pre_val: 3b8e
# pre_val: 3b8f
# pre_val: 3b90
# pre_val: 3b91
# pre_val: 3b92
# pre_val: 3b93
# pre_val: 3b94
# pre_val: 3b95
# pre_val: 3b96
# pre_val: 3b97
# pre_val: 3b98
# pre_val: 3b99
# pre_val: 3b9a
# pre_val: 3b9b
# pre_val: 3b9c
# pre_val: 3b9d
# pre_val: 3b9e
# pre_val: 3b9f
# pre_val: 3ba0
# pre_val: 3ba1
# pre_val: 3ba2
# pre_val: 3ba3
# pre_val: 3ba4
# pre_val: 3ba5
# pre_val: 3ba6
# pre_val: 3ba7
# pre_val: 3ba8
# pre_val: 3ba9
# pre_val: 3baa
# pre_val: 3bab
# pre_val: 3bac
# pre_val: 3bad
# pre_val: 3bae
# pre_val: 3baf
# pre_val: 3bb0
# pre_val: 3bb1
# pre_val: 3bb2
# pre_val: 3bb3
# pre_val: 3bb4
# pre_val: 3bb5
# pre_val: 3bb6
# pre_val: 3bb7
# pre_val: 3bb8
# pre_val: 3bb9
# pre_val: 3bba
# pre_val: 3bbb
# pre_val: 3bbc
# pre_val: 3bbd
# pre_val: 3bbe
# pre_val: 3bbf
# pre_val: 3bc0
# pre_val: 3bc1
# pre_val: 3bc2
# pre_val: 3bc3
# pre_val: 3bc4
# pre_val: 3bc5
# pre_val: 3bc6
# pre_val: 3bc7
# pre_val: 3bc8
# pre_val: 3bc9
# pre_val: 3bca
# pre_val: 3bcb
# pre_val: 3bcc
# pre_val: 3bcd
# pre_val: 3bce
# pre_val: 3bcf
# pre_val: 3bd0
# pre_val: 3bd1
# pre_val: 3bd2
# pre_val: 3bd3
# pre_val: 3bd4
# pre_val: 3bd5
# pre_val: 3bd6
# pre_val: 3bd7
# pre_val: 3bd8
# pre_val: 3bd9
# pre_val: 3bda
# pre_val: 3bdb
# pre_val: 3bdc
# pre_val: 3bdd
# pre_val: 3bde
# pre_val: 3bdf
# pre_val: 3be0
# pre_val: 3be1
# pre_val: 3be2
# pre_val: 3be3
# pre_val: 3be4
# pre_val: 3be5
# pre_val: 3be6
# pre_val: 3be7
# pre_val: 3be8
# pre_val: 3be9
# pre_val: 3bea
# pre_val: 3beb
# pre_val: 3bec
# pre_val: 3bed
# pre_val: 3bee
# pre_val: 3bef
# pre_val: 3bf0
# pre_val: 3bf1
# pre_val: 3bf2
# pre_val: 3bf3
# pre_val: 3bf4
# pre_val: 3bf5
# pre_val: 3bf6
# pre_val: 3bf7
# pre_val: 3bf8
# pre_val: 3bf9
# pre_val: 3bfa
# pre_val: 3bfb
# pre_val: 3bfc
# pre_val: 3bfd
# pre_val: 3bfe
# pre_val: 3bff
# pre_val: 3c00
# pre_val: 3c01
# pre_val: 3c02
# pre_val: 3c03
# pre_val: 3c04
# pre_val: 3c05
# pre_val: 3c06
# pre_val: 3c07
# pre_val: 3c08
# pre_val: 3c09
# pre_val: 3c0a
# pre_val: 3c0b
# pre_val: 3c0c
# pre_val: 3c0d
# pre_val: 3c0e
# pre_val: 3c0f
# pre_val: 3c10
# pre_val: 3c11
# pre_val: 3c12
# pre_val: 3c13
# pre_val: 3c14
# pre_val: 3c15
# pre_val: 3c16
# pre_val: 3c17
# pre_val: 3c18
# pre_val: 3c19
# pre_val: 3c1a
# pre_val: 3c1b
# pre_val: 3c1c
# pre_val: 3c1d
# pre_val: 3c1e
# pre_val: 3c1f
# pre_val: 3c20
# pre_val: 3c21
# pre_val: 3c22
# pre_val: 3c23
# pre_val: 3c24
# pre_val: 3c25
# pre_val: 3c26
# pre_val: 3c27
# pre_val: 3c28
# pre_val: 3c29
# pre_val: 3c2a
# pre_val: 3c2b
# pre_val: 3c2c
# pre_val: 3c2d
# pre_val: 3c2e
# pre_val: 3c2f
# pre_val: 3c30
# pre_val: 3c31
# pre_val: 3c32
# pre_val: 3c33
# pre_val: 3c34
# pre_val: 3c35
# pre_val: 3c36
# pre_val: 3c37
# pre_val: 3c38
# pre_val: 3c39
# pre_val: 3c3a
# pre_val: 3c3b
# pre_val: 3c3c
# pre_val: 3c3d
# pre_val: 3c3e
# pre_val: 3c3f
# pre_val: 3c40
# pre_val: 3c41
# pre_val: 3c42
# pre_val: 3c43
# pre_val: 3c44
# pre_val: 3c45
# pre_val: 3c46
# pre_val: 3c47
# pre_val: 3c48
# pre_val: 3c49
# pre_val: 3c4a
# pre_val: 3c4b
# pre_val: 3c4c
# pre_val: 3c4d
# pre_val: 3c4e
# pre_val: 3c4f
# pre_val: 3c50
# pre_val: 3c51
# pre_val: 3c52
# pre_val: 3c53
# pre_val: 3c54
# pre_val: 3c55
# pre_val: 3c56
# pre_val: 3c57
# pre_val: 3c58
# pre_val: 3c59
# pre_val: 3c5a
# pre_val: 3c5b
# pre_val: 3c5c
# pre_val: 3c5d
# pre_val: 3c5e
# pre_val: 3c5f
# pre_val: 3c60
# pre_val: 3c61
# pre_val: 3c62
# pre_val: 3c63
# pre_val: 3c64
# pre_val: 3c65
# pre_val: 3c66
# pre_val: 3c67
# pre_val: 3c68
# pre_val: 3c69
# pre_val: 3c6a
# pre_val: 3c6b
# pre_val: 3c6c
# pre_val: 3c6d
# pre_val: 3c6e
# pre_val: 3c6f
# pre_val: 3c70
# pre_val: 3c71
# pre_val: 3c72
# pre_val: 3c73
# pre_val: 3c74
# pre_val: 3c75
# pre_val: 3c76
# pre_val: 3c77
# pre_val: 3c78
# pre_val: 3c79
# pre_val: 3c7a
# pre_val: 3c7b
# pre_val: 3c7c
# pre_val: 3c7d
# pre_val: 3c7e
# pre_val: 3c7f
# pre_val: 3c80
# pre_val: 3c81
# pre_val: 3c82
# pre_val: 3c83
# pre_val: 3c84
# pre_val: 3c85
# pre_val: 3c86
# pre_val: 3c87
# pre_val: 3c88
# pre_val: 3c89
# pre_val: 3c8a
# pre_val: 3c8b
# pre_val: 3c8c
# pre_val: 3c8d
# pre_val: 3c8e
# pre_val: 3c8f
# pre_val: 3c90
# pre_val: 3c91
# pre_val: 3c92
# pre_val: 3c93
# pre_val: 3c94
# pre_val: 3c95
# pre_val: 3c96
# pre_val: 3c97
# pre_val: 3c98
# pre_val: 3c99
# pre_val: 3c9a
# pre_val: 3c9b
# pre_val: 3c9c
# pre_val: 3c9d
# pre_val: 3c9e
# pre_val: 3c9f
# pre_val: 3ca0
# pre_val: 3ca1
# pre_val: 3ca2
# pre_val: 3ca3
# pre_val: 3ca4
# pre_val: 3ca5
# pre_val: 3ca6
# pre_val: 3ca7
# pre_val: 3ca8
# pre_val: 3ca9
# pre_val: 3caa
# pre_val: 3cab
# pre_val: 3cac
# pre_val: 3cad
# pre_val: 3cae
# pre_val: 3caf
# pre_val: 3cb0
# pre_val: 3cb1
# pre_val: 3cb2
# pre_val: 3cb3
# pre_val: 3cb4
# pre_val: 3cb5
# pre_val: 3cb6
# pre_val: 3cb7
# pre_val: 3cb8
# pre_val: 3cb9
# pre_val: 3cba
# pre_val: 3cbb
# pre_val: 3cbc
# pre_val: 3cbd
# pre_val: 3cbe
# pre_val: 3cbf
# pre_val: 3cc0
# pre_val: 3cc1
# pre_val: 3cc2
# pre_val: 3cc3
# pre_val: 3cc4
# pre_val: 3cc5
# pre_val: 3cc6
# pre_val: 3cc7
# pre_val: 3cc8
# pre_val: 3cc9
# pre_val: 3cca
# pre_val: 3ccb
# pre_val: 3ccc
# pre_val: 3ccd
# pre_val: 3cce
# pre_val: 3ccf
# pre_val: 3cd0
# pre_val: 3cd1
# pre_val: 3cd2
# pre_val: 3cd3
# pre_val: 3cd4
# pre_val: 3cd5
# pre_val: 3cd6
# pre_val: 3cd7
# pre_val: 3cd8
# pre_val: 3cd9
# pre_val: 3cda
# pre_val: 3cdb
# pre_val: 3cdc
# pre_val: 3cdd
# pre_val: 3cde
# pre_val: 3cdf
# pre_val: 3ce0
# pre_val: 3ce1
# pre_val: 3ce2
# pre_val: 3ce3
# pre_val: 3ce4
# pre_val: 3ce5
# pre_val: 3ce6
# pre_val: 3ce7
# pre_val: 3ce8
# pre_val: 3ce9
# pre_val: 3cea
# pre_val: 3ceb
# pre_val: 3cec
# pre_val: 3ced
# pre_val: 3cee
# pre_val: 3cef
# pre_val: 3cf0
# pre_val: 3cf1
# pre_val: 3cf2
# pre_val: 3cf3
# pre_val: 3cf4
# pre_val: 3cf5
# pre_val: 3cf6
# pre_val: 3cf7
# pre_val: 3cf8
# pre_val: 3cf9
# pre_val: 3cfa
# pre_val: 3cfb
# pre_val: 3cfc
# pre_val: 3cfd
# pre_val: 3cfe
# pre_val: 3cff
# pre_val: 3d00
# pre_val: 3d01
# pre_val: 3d02
# pre_val: 3d03
# pre_val: 3d04
# pre_val: 3d05
# pre_val: 3d06
# pre_val: 3d07
# pre_val: 3d08
# pre_val: 3d09
# pre_val: 3d0a
# pre_val: 3d0b
# pre_val: 3d0c
# pre_val: 3d0d
# pre_val: 3d0e
# pre_val: 3d0f
# pre_val: 3d10
# pre_val: 3d11
# pre_val: 3d12
# pre_val: 3d13
# pre_val: 3d14
# pre_val: 3d15
# pre_val: 3d16
# pre_val: 3d17
# pre_val: 3d18
# pre_val: 3d19
# pre_val: 3d1a
# pre_val: 3d1b
# pre_val: 3d1c
# pre_val: 3d1d
# pre_val: 3d1e
# pre_val: 3d1f
# pre_val: 3d20
# pre_val: 3d21
# pre_val: 3d22
# pre_val: 3d23
# pre_val: 3d24
# pre_val: 3d25
# pre_val: 3d26
# pre_val: 3d27
# pre_val: 3d28
# pre_val: 3d29
# pre_val: 3d2a
# pre_val: 3d2b
# pre_val: 3d2c
# pre_val: 3d2d
# pre_val: 3d2e
# pre_val: 3d2f
# pre_val: 3d30
# pre_val: 3d31
# pre_val: 3d32
# pre_val: 3d33
# pre_val: 3d34
# pre_val: 3d35
# pre_val: 3d36
# pre_val: 3d37
# pre_val: 3d38
# pre_val: 3d39
# pre_val: 3d3a
# pre_val: 3d3b
# pre_val: 3d3c
# pre_val: 3d3d
# pre_val: 3d3e
# pre_val: 3d3f
# pre_val: 3d40
# pre_val: 3d41
# pre_val: 3d42
# pre_val: 3d43
# pre_val: 3d44
# pre_val: 3d45
# pre_val: 3d46
# pre_val: 3d47
# pre_val: 3d48
# pre_val: 3d49
# pre_val: 3d4a
# pre_val: 3d4b
# pre_val: 3d4c
# pre_val: 3d4d
# pre_val: 3d4e
# pre_val: 3d4f
# pre_val: 3d50
# pre_val: 3d51
# pre_val: 3d52
# pre_val: 3d53
# pre_val: 3d54
# pre_val: 3d55
# pre_val: 3d56
# pre_val: 3d57
# pre_val: 3d58
# pre_val: 3d59
# pre_val: 3d5a
# pre_val: 3d5b
# pre_val: 3d5c
# pre_val: 3d5d
# pre_val: 3d5e
# pre_val: 3d5f
# pre_val: 3d60
# pre_val: 3d61
# pre_val: 3d62
# pre_val: 3d63
# pre_val: 3d64
# pre_val: 3d65
# pre_val: 3d66
# pre_val: 3d67
# pre_val: 3d68
# pre_val: 3d69
# pre_val: 3d6a
# pre_val: 3d6b
# pre_val: 3d6c
# pre_val: 3d6d
# pre_val: 3d6e
# pre_val: 3d6f
# pre_val: 3d70
# pre_val: 3d71
# pre_val: 3d72
# pre_val: 3d73
# pre_val: 3d74
# pre_val: 3d75
# pre_val: 3d76
# pre_val: 3d77
# pre_val: 3d78
# pre_val: 3d79
# pre_val: 3d7a
# pre_val: 3d7b
# pre_val: 3d7c
# pre_val: 3d7d
# pre_val: 3d7e
# pre_val: 3d7f
# pre_val: 3d80
# pre_val: 3d81
# pre_val: 3d82
# pre_val: 3d83
# pre_val: 3d84
# pre_val: 3d85
# pre_val: 3d86
# pre_val: 3d87
# pre_val: 3d88
# pre_val: 3d89
# pre_val: 3d8a
# pre_val: 3d8b
# pre_val: 3d8c
# pre_val: 3d8d
# pre_val: 3d8e
# pre_val: 3d8f
# pre_val: 3d90
# pre_val: 3d91
# pre_val: 3d92
# pre_val: 3d93
# pre_val: 3d94
# pre_val: 3d95
# pre_val: 3d96
# pre_val: 3d97
# pre_val: 3d98
# pre_val: 3d99
# pre_val: 3d9a
# pre_val: 3d9b
# pre_val: 3d9c
# pre_val: 3d9d
# pre_val: 3d9e
# pre_val: 3d9f
# pre_val: 3da0
# pre_val: 3da1
# pre_val: 3da2
# pre_val: 3da3
# pre_val: 3da4
# pre_val: 3da5
# pre_val: 3da6
# pre_val: 3da7
# pre_val: 3da8
# pre_val: 3da9
# pre_val: 3daa
# pre_val: 3dab
# pre_val: 3dac
# pre_val: 3dad
# pre_val: 3dae
# pre_val: 3daf
# pre_val: 3db0
# pre_val: 3db1
# pre_val: 3db2
# pre_val: 3db3
# pre_val: 3db4
# pre_val: 3db5
# pre_val: 3db6
# pre_val: 3db7
# pre_val: 3db8
# pre_val: 3db9
# pre_val: 3dba
# pre_val: 3dbb
# pre_val: 3dbc
# pre_val: 3dbd
# pre_val: 3dbe
# pre_val: 3dbf
# pre_val: 3dc0
# pre_val: 3dc1
# pre_val: 3dc2
# pre_val: 3dc3
# pre_val: 3dc4
# pre_val: 3dc5
# pre_val: 3dc6
# pre_val: 3dc7
# pre_val: 3dc8
# pre_val: 3dc9
# pre_val: 3dca
# pre_val: 3dcb
# pre_val: 3dcc
# pre_val: 3dcd
# pre_val: 3dce
# pre_val: 3dcf
# pre_val: 3dd0
# pre_val: 3dd1
# pre_val: 3dd2
# pre_val: 3dd3
# pre_val: 3dd4
# pre_val: 3dd5
# pre_val: 3dd6
# pre_val: 3dd7
# pre_val: 3dd8
# pre_val: 3dd9
# pre_val: 3dda
# pre_val: 3ddb
# pre_val: 3ddc
# pre_val: 3ddd
# pre_val: 3dde
# pre_val: 3ddf
# pre_val: 3de0
# pre_val: 3de1
# pre_val: 3de2
# pre_val: 3de3
# pre_val: 3de4
# pre_val: 3de5
# pre_val: 3de6
# pre_val: 3de7
# pre_val: 3de8
# pre_val: 3de9
# pre_val: 3dea
# pre_val: 3deb
# pre_val: 3dec
# pre_val: 3ded
# pre_val: 3dee
# pre_val: 3def
# pre_val: 3df0
# pre_val: 3df1
# pre_val: 3df2
# pre_val: 3df3
# pre_val: 3df4
# pre_val: 3df5
# pre_val: 3df6
# pre_val: 3df7
# pre_val: 3df8
# pre_val: 3df9
# pre_val: 3dfa
# pre_val: 3dfb
# pre_val: 3dfc
# pre_val: 3dfd
# pre_val: 3dfe
# pre_val: 3dff
# pre_val: 3e00
# pre_val: 3e01
# pre_val: 3e02
# pre_val: 3e03
# pre_val: 3e04
# pre_val: 3e05
# pre_val: 3e06
# pre_val: 3e07
# pre_val: 3e08
# pre_val: 3e09
# pre_val: 3e0a
# pre_val: 3e0b
# pre_val: 3e0c
# pre_val: 3e0d
# pre_val: 3e0e
# pre_val: 3e0f
# pre_val: 3e10
# pre_val: 3e11
# pre_val: 3e12
# pre_val: 3e13
# pre_val: 3e14
# pre_val: 3e15
# pre_val: 3e16
# pre_val: 3e17
# pre_val: 3e18
# pre_val: 3e19
# pre_val: 3e1a
# pre_val: 3e1b
# pre_val: 3e1c
# pre_val: 3e1d
# pre_val: 3e1e
# pre_val: 3e1f
# pre_val: 3e20
# pre_val: 3e21
# pre_val: 3e22
# pre_val: 3e23
# pre_val: 3e24
# pre_val: 3e25
# pre_val: 3e26
# pre_val: 3e27
# pre_val: 3e28
# pre_val: 3e29
# pre_val: 3e2a
# pre_val: 3e2b
# pre_val: 3e2c
# pre_val: 3e2d
# pre_val: 3e2e
# pre_val: 3e2f
# pre_val: 3e30
# pre_val: 3e31
# pre_val: 3e32
# pre_val: 3e33
# pre_val: 3e34
# pre_val: 3e35
# pre_val: 3e36
# pre_val: 3e37
# pre_val: 3e38
# pre_val: 3e39
# pre_val: 3e3a
# pre_val: 3e3b
# pre_val: 3e3c
# pre_val: 3e3d
# pre_val: 3e3e
# pre_val: 3e3f
# pre_val: 3e40
# pre_val: 3e41
# pre_val: 3e42
# pre_val: 3e43
# pre_val: 3e44
# pre_val: 3e45
# pre_val: 3e46
# pre_val: 3e47
# pre_val: 3e48
# pre_val: 3e49
# pre_val: 3e4a
# pre_val: 3e4b
# pre_val: 3e4c
# pre_val: 3e4d
# pre_val: 3e4e
# pre_val: 3e4f
# pre_val: 3e50
# pre_val: 3e51
# pre_val: 3e52
# pre_val: 3e53
# pre_val: 3e54
# pre_val: 3e55
# pre_val: 3e56
# pre_val: 3e57
# pre_val: 3e58
# pre_val: 3e59
# pre_val: 3e5a
# pre_val: 3e5b
# pre_val: 3e5c
# pre_val: 3e5d
# pre_val: 3e5e
# pre_val: 3e5f
# pre_val: 3e60
# pre_val: 3e61
# pre_val: 3e62
# pre_val: 3e63
# pre_val: 3e64
# pre_val: 3e65
# pre_val: 3e66
# pre_val: 3e67
# pre_val: 3e68
# pre_val: 3e69
# pre_val: 3e6a
# pre_val: 3e6b
# pre_val: 3e6c
# pre_val: 3e6d
# pre_val: 3e6e
# pre_val: 3e6f
# pre_val: 3e70
# pre_val: 3e71
# pre_val: 3e72
# pre_val: 3e73
# pre_val: 3e74
# pre_val: 3e75
# pre_val: 3e76
# pre_val: 3e77
# pre_val: 3e78
# pre_val: 3e79
# pre_val: 3e7a
# pre_val: 3e7b
# pre_val: 3e7c
# pre_val: 3e7d
# pre_val: 3e7e
# pre_val: 3e7f

# %%
fpath_img_precrop_hex
# Out:
# 'tb_data/ap_fixed_16_15/100x160_to_48x48x1/img_precrop_hex_INDEX.bin'

# %% [markdown]
# Now, iterate through some possible crops, including all corners and some edges, and save each one

# %%
Y1_range = [0, 37, IN_ROWS-OUT_ROWS]
X1_range = [0, 59, IN_COLS-OUT_COLS]

for Y1 in Y1_range:
    Y2 = Y1+OUT_ROWS
    for X1 in X1_range:
        X2 = X1+OUT_COLS

        img_postcrop_float = img_precrop_float[Y1:Y2, X1:X2].astype(np.float32)
        fpath_img_postcrop = os.path.join(top_level_dir, f"Y1_{Y1}", f"X1_{X1}", f"img_postcrop{DATA_STRING_INSERT}.bin")
        os.makedirs(os.path.dirname(fpath_img_postcrop), exist_ok=True)
        with open(fpath_img_postcrop, "w") as f:
            for row in img_postcrop_float:
                for val in row:
                    val_fixed = float_to_fixed_point(val, FP_TOTAL, FP_FRAC)
                    f.write(f"{val_fixed}\n")

fig, (ax1, ax2) = plt.subplots(1,2,figsize=(12,6))
ax1.imshow(img_precrop_float, vmin=0, vmax=IN_ROWS*IN_COLS)
ax1.set_title("Pre-crop")
ax2.imshow(img_postcrop_float, vmin=0, vmax=IN_ROWS*IN_COLS)
ax2.set_title("Post-crop")
plt.show(fig)
plt.close(fig)
