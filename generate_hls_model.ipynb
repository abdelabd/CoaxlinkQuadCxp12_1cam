# %%
import os
import copy
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Model, Sequential

import hls4ml
from hls4ml.converters.keras_to_hls import parse_default_keras_layer
from hls4ml.model.attributes import ConfigurableAttribute, TypeAttribute
from hls4ml.model.types import FixedPrecisionType, RoundingMode, SaturationMode
from hls4ml.model.attributes import Attribute

import h5py

import qkeras
from qkeras.estimate import print_qstats
from qkeras.utils import model_quantize
from qkeras.utils import quantized_model_dump
from qkeras import QActivation, QDense, QConv2DBatchnorm

# Source the Vivado path
os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']

np.random.seed(0)
tf.random.set_seed(0)
# Out:
# 2025-05-29 17:18:41.203704: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-29 17:18:41.335273: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-29 17:18:41.341192: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:41.341215: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-05-29 17:18:41.848822: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:41.848910: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:41.848918: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from recurrent.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# /home/aelabd/RHEED/hls4ml/hls4ml/converters/__init__.py:29: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)

# %% [markdown]
# Globals

# %% [markdown]
# # 1. Load Keras model

# %%
KERAS_DIR = "keras_models"
RTL_DIR = "rtl_models"

def dice_loss(y_true, y_pred, delta=0.6):
    error = y_true - y_pred
    is_small = tf.abs(error) <= delta
    squared_loss = 0.5 * tf.square(error)
    linear_loss = delta * (tf.abs(error) - 0.5 * delta)
    return tf.reduce_mean(tf.where(is_small, squared_loss, linear_loss))

fpath_model_keras = os.path.join(KERAS_DIR, "model.keras")
with tf.keras.utils.custom_object_scope({'dice_loss': dice_loss,
                                         'QConv2DBatchnorm': QConv2DBatchnorm,
                                         'QActivation': QActivation,
                                         'QDense': QDense
                                         }):
        model = tf.keras.models.load_model(fpath_model_keras)

model.summary()
# Out:
# 2025-05-29 17:18:45.738888: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:967] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-05-29 17:18:45.739118: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739217: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739284: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739349: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739405: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739462: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739518: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739573: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2025-05-29 17:18:45.739627: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-05-29 17:18:45.740899: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/aelabd/miniconda3/envs/rheed_hls4ml_dev/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /home/aelabd/miniconda3/envs/rheed_hls4ml_dev/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv2d_batchnorm_5 (QConv  (None, 46, 46, 8)        113
#  2DBatchnorm)
#
#  q_activation_8 (QActivation  (None, 46, 46, 8)        0
#  )
#
#  max_pooling2d_5 (MaxPooling  (None, 11, 11, 8)        0
#  2D)
#
#  q_conv2d_batchnorm_6 (QConv  (None, 9, 9, 16)         1233
#  2DBatchnorm)
#
#  q_activation_9 (QActivation  (None, 9, 9, 16)         0
#  )
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  q_conv2d_batchnorm_7 (QConv  (None, 2, 2, 32)         4769
#  2DBatchnorm)
#
#  q_activation_10 (QActivatio  (None, 2, 2, 32)         0
#  n)
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  q_dense_5 (QDense)          (None, 32)                1056
#
#  q_activation_11 (QActivatio  (None, 32)               0
#  n)
#
#  q_dense_6 (QDense)          (None, 5)                 165
#
# =================================================================
# Total params: 7,336
# Trainable params: 7,221
# Non-trainable params: 115
# _________________________________________________________________

# %%
import qkeras as qk

def print_quantization_info(model):
    for layer in model.layers:
        print(f"Layer Name: {layer.name}")
        print(f"Type: {layer.__class__.__name__}")
        
        # Helper function to handle both quantizer objects and config dicts
        def process_quantizer(quantizer, prefix=""):
            if quantizer:
                if isinstance(quantizer, dict):
                    # Handle dictionary config
                    class_name = quantizer.get("class_name", "UnknownQuantizer")
                    config = quantizer.get("config", {})
                else:
                    # Handle object with potential get_config()
                    class_name = quantizer.__class__.__name__
                    config = quantizer.get_config() if hasattr(quantizer, "get_config") else {}
                
                print(f"  {prefix}Quantizer: {class_name}")
                print(f"  {prefix}Config: {config}")
            else:
                print(f"  No {prefix}Quantizer")

        # Check for QKeras layers with kernel/bias quantizers
        if isinstance(layer, (qk.QDense, qk.QConv2D, qk.QConv1D, 
                            qk.QConv2DTranspose, qk.QDepthwiseConv2D)):
            # Kernel quantizer
            process_quantizer(layer.kernel_quantizer, "Kernel ")
            
            # Bias quantizer
            process_quantizer(layer.bias_quantizer, "Bias ")
            
            # Activation quantizer
            activation = layer.activation
            if activation:
                if isinstance(activation, dict) or hasattr(activation, "get_config"):
                    process_quantizer(activation, "Activation ")
                else:
                    print(f"  Activation: {activation} (Not Quantized)")
            else:
                print("  No Activation")

        # Check for QActivation layers
        elif isinstance(layer, qk.QActivation):
            process_quantizer(layer.quantizer, "Activation ")
        
        print("-" * 50)

print_quantization_info(model)
# Out:
# Layer Name: q_conv2d_batchnorm_5
# Type: QConv2DBatchnorm
#   Kernel Quantizer: quantized_bits
#   Kernel Config: {'bits': 8, 'integer': 0, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Bias Quantizer: quantized_bits
#   Bias Config: {'bits': 8, 'integer': 0, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Activation: <function linear at 0x7ff5b1710a60> (Not Quantized)
# --------------------------------------------------
# Layer Name: q_activation_8
# Type: QActivation
#   Activation Quantizer: quantized_relu
#   Activation Config: {'bits': 8, 'integer': 2, 'use_sigmoid': 0, 'negative_slope': 0.0, 'use_stochastic_rounding': False, 'relu_upper_bound': None, 'qnoise_factor': 1.0}
# --------------------------------------------------
# Layer Name: max_pooling2d_5
# Type: MaxPooling2D
# --------------------------------------------------
# Layer Name: q_conv2d_batchnorm_6
# Type: QConv2DBatchnorm
#   Kernel Quantizer: quantized_bits
#   Kernel Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Bias Quantizer: quantized_bits
#   Bias Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Activation: <function linear at 0x7ff5b1710a60> (Not Quantized)
# --------------------------------------------------
# Layer Name: q_activation_9
# Type: QActivation
#   Activation Quantizer: quantized_relu
#   Activation Config: {'bits': 8, 'integer': 2, 'use_sigmoid': 0, 'negative_slope': 0.0, 'use_stochastic_rounding': False, 'relu_upper_bound': None, 'qnoise_factor': 1.0}
# --------------------------------------------------
# Layer Name: max_pooling2d_6
# Type: MaxPooling2D
# --------------------------------------------------
# Layer Name: q_conv2d_batchnorm_7
# Type: QConv2DBatchnorm
#   Kernel Quantizer: quantized_bits
#   Kernel Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Bias Quantizer: quantized_bits
#   Bias Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Activation: <function linear at 0x7ff5b1710a60> (Not Quantized)
# --------------------------------------------------
# Layer Name: q_activation_10
# Type: QActivation
#   Activation Quantizer: quantized_relu
#   Activation Config: {'bits': 8, 'integer': 2, 'use_sigmoid': 0, 'negative_slope': 0.0, 'use_stochastic_rounding': False, 'relu_upper_bound': None, 'qnoise_factor': 1.0}
# --------------------------------------------------
# Layer Name: max_pooling2d_7
# Type: MaxPooling2D
# --------------------------------------------------
# Layer Name: global_average_pooling2d_1
# Type: GlobalAveragePooling2D
# --------------------------------------------------
# Layer Name: q_dense_5
# Type: QDense
#   Kernel Quantizer: quantized_bits
#   Kernel Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Bias Quantizer: quantized_bits
#   Bias Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Activation: <function linear at 0x7ff5b1710a60> (Not Quantized)
# --------------------------------------------------
# Layer Name: q_activation_11
# Type: QActivation
#   Activation Quantizer: quantized_relu
#   Activation Config: {'bits': 8, 'integer': 2, 'use_sigmoid': 0, 'negative_slope': 0.0, 'use_stochastic_rounding': False, 'relu_upper_bound': None, 'qnoise_factor': 1.0}
# --------------------------------------------------
# Layer Name: q_dense_6
# Type: QDense
#   Kernel Quantizer: quantized_bits
#   Kernel Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Bias Quantizer: quantized_bits
#   Bias Config: {'bits': 8, 'integer': 2, 'symmetric': 0, 'alpha': 1, 'keep_negative': True, 'use_stochastic_rounding': False, 'qnoise_factor': 1.0}
#   Activation: <function linear at 0x7ff5b1710a60> (Not Quantized)
# --------------------------------------------------

# %% [markdown]
# # 2. Create hls4ml model
#
# For now, skip evaluation and creating benchmark results. JUST convert it.

# %%
# Generate the configuration from the Keras model
FP_TOTAL = 8
FP_INT = 0
REUSE_FACTOR = 32

config = hls4ml.utils.config_from_keras_model(model, granularity='model', backend="Vivado")
config['Model']['Precision']['default'] = f"ap_fixed<{FP_TOTAL},{FP_INT}>"
config['Model']['ReuseFactor'] = REUSE_FACTOR
config['Model']['Strategy'] = 'Resource'

# Attempt conversion on simplified model
output_dir = f"rtl_models/model2"
hls_model = hls4ml.converters.convert_from_keras_model(
    model, 
    hls_config=config, 
    output_dir=output_dir, 
    # backend="Vitis",
    backend="Vivado",
    part='xcku035-fbva676-2-e', 
    io_type="io_stream"
)

# hls_model.compile()

print("")
print(hls_model.config.config['OutputDir'])
# Out:
# Interpreting Sequential
# Topology:
# Layer name: q_conv2d_batchnorm_5_input, layer type: InputLayer, input shapes: [[None, 48, 48, 1]], output shape: [None, 48, 48, 1]
# Layer name: q_conv2d_batchnorm_5, layer type: QConv2DBatchnorm, input shapes: [[None, 48, 48, 1]], output shape: [None, 46, 46, 8]
# Layer name: q_activation_8, layer type: Activation, input shapes: [[None, 46, 46, 8]], output shape: [None, 46, 46, 8]
# Layer name: max_pooling2d_5, layer type: MaxPooling2D, input shapes: [[None, 46, 46, 8]], output shape: [None, 11, 11, 8]
# Layer name: q_conv2d_batchnorm_6, layer type: QConv2DBatchnorm, input shapes: [[None, 11, 11, 8]], output shape: [None, 9, 9, 16]
# Layer name: q_activation_9, layer type: Activation, input shapes: [[None, 9, 9, 16]], output shape: [None, 9, 9, 16]
# Layer name: max_pooling2d_6, layer type: MaxPooling2D, input shapes: [[None, 9, 9, 16]], output shape: [None, 4, 4, 16]
# Layer name: q_conv2d_batchnorm_7, layer type: QConv2DBatchnorm, input shapes: [[None, 4, 4, 16]], output shape: [None, 2, 2, 32]
# Layer name: q_activation_10, layer type: Activation, input shapes: [[None, 2, 2, 32]], output shape: [None, 2, 2, 32]
# Layer name: max_pooling2d_7, layer type: MaxPooling2D, input shapes: [[None, 2, 2, 32]], output shape: [None, 1, 1, 32]
# Layer name: global_average_pooling2d_1, layer type: GlobalAveragePooling2D, input shapes: [[None, 1, 1, 32]], output shape: [None, 32]
# Layer name: q_dense_5, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: q_activation_11, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: q_dense_6, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 5]
# Interpreting Sequential
# Topology:
# Layer name: q_conv2d_batchnorm_5_input, layer type: InputLayer, input shapes: [[None, 48, 48, 1]], output shape: [None, 48, 48, 1]
# Layer name: q_conv2d_batchnorm_5, layer type: QConv2DBatchnorm, input shapes: [[None, 48, 48, 1]], output shape: [None, 46, 46, 8]
# Layer name: q_activation_8, layer type: Activation, input shapes: [[None, 46, 46, 8]], output shape: [None, 46, 46, 8]
# Layer name: max_pooling2d_5, layer type: MaxPooling2D, input shapes: [[None, 46, 46, 8]], output shape: [None, 11, 11, 8]
# Layer name: q_conv2d_batchnorm_6, layer type: QConv2DBatchnorm, input shapes: [[None, 11, 11, 8]], output shape: [None, 9, 9, 16]
# Layer name: q_activation_9, layer type: Activation, input shapes: [[None, 9, 9, 16]], output shape: [None, 9, 9, 16]
# Layer name: max_pooling2d_6, layer type: MaxPooling2D, input shapes: [[None, 9, 9, 16]], output shape: [None, 4, 4, 16]
# Layer name: q_conv2d_batchnorm_7, layer type: QConv2DBatchnorm, input shapes: [[None, 4, 4, 16]], output shape: [None, 2, 2, 32]
# Layer name: q_activation_10, layer type: Activation, input shapes: [[None, 2, 2, 32]], output shape: [None, 2, 2, 32]
# Layer name: max_pooling2d_7, layer type: MaxPooling2D, input shapes: [[None, 2, 2, 32]], output shape: [None, 1, 1, 32]
# Layer name: global_average_pooling2d_1, layer type: GlobalAveragePooling2D, input shapes: [[None, 1, 1, 32]], output shape: [None, 32]
# Layer name: q_dense_5, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: q_activation_11, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: q_dense_6, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 5]
# Creating HLS model
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Invalid ReuseFactor=32 in layer "q_conv2d_batchnorm_5".Using ReuseFactor=36 instead. Valid ReuseFactor(s): 1,3,9,18,36,72.
# WARNING: Invalid ReuseFactor=32 in layer "q_conv2d_batchnorm_6".Using ReuseFactor=36 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,9,12,18,24,36,72,144,288,576,1152.
# WARNING: Invalid ReuseFactor=32 in layer "q_conv2d_batchnorm_7".Using ReuseFactor=36 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,9,12,16,18,24,36,48,72,144,288,576,1152,2304,4608.
#
# rtl_models/model2

# %%
hls_model.predict(np.full((1, 48, 48), 7).astype(float))
# Out:
# array([ 0.2890625 ,  0.4453125 ,  0.41796875,  0.43359375, -0.02734375])

# %%
hls_model.config.config
# Out:
# {'OutputDir': 'rtl_models/model',
#  'ProjectName': 'myproject',
#  'Backend': 'Vivado',
#  'Version': '1.0.0',
#  'Part': 'xcku035-fbva676-2-e',
#  'ClockPeriod': 5,
#  'ClockUncertainty': '12.5%',
#  'IOType': 'io_stream',
#  'HLSConfig': {'Model': {'Precision': {'default': 'ap_fixed<8,0>'},
#    'ReuseFactor': 32,
#    'Strategy': 'Resource',
#    'BramFactor': 1000000000,
#    'TraceOutput': False}},
#  'WriterConfig': {'Namespace': None,
#   'WriteWeightsTxt': True,
#   'WriteTar': False},
#  'KerasModel': <keras.engine.sequential.Sequential at 0x7f2604f77c40>,
#  'InputData': None,
#  'OutputPredictions': None,
#  'Stamp': '184e6475'}

# %% [markdown]
# # Generate RTL model

# %%
hls_model.build(csim=False, synth=True, vsynth=True)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2019.1 (64-bit)
#   **** SW Build 2552052 on Fri May 24 14:47:09 MDT 2019
#   **** IP Build 2548770 on Fri May 24 18:01:18 MDT 2019
#     ** Copyright 1986-2019 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vivado/2019.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vivado/2019.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'aelabd' on host 'DESKTOP-Q0UCNGC.' (Linux_x86_64 version 5.15.133.1-microsoft-standard-WSL2) on Thu May 29 16:46:53 CEST 2025
# INFO: [HLS 200-10] On os Ubuntu 24.04 LTS
# INFO: [HLS 200-10] In directory '/home/aelabd/RHEED/CoaxlinkQuadCxp12_1cam/rtl_models/model'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/aelabd/RHEED/CoaxlinkQuadCxp12_1cam/rtl_models/model/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/aelabd/RHEED/CoaxlinkQuadCxp12_1cam/rtl_models/model/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xcku035-fbva676-2-e'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 214-111] Streams will behave like static variables inside a dataflow region: firmware/myproject.cpp:38:24
# WARNING: [HLS 200-471] Dataflow form checks found 1 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:14 ; elapsed = 00:00:15 . Memory (MB): peak = 814.527 ; gain = 126.000 ; free physical = 24954 ; free virtual = 35635
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:14 ; elapsed = 00:00:15 . Memory (MB): peak = 814.527 ; gain = 126.000 ; free physical = 24954 ; free virtual = 35635
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'PixelLoop' (firmware/nnet_utils/nnet_pooling_stream.h:483) in function 'void nnet::compute_global_pool<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config14>(FORWARD_REFERENCE const&, FORWARD_REFERENCE::accum_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'void nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>(FORWARD_REFERENCE const&, ap_shift_reg<FORWARD_REFERENCE::value_type, FORWARD_REFERENCE::in_width> (*) [FORWARD_REFERENCE::n_chan], FORWARD_REFERENCE::value_type*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'void nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>(FORWARD_REFERENCE const&, ap_shift_reg<FORWARD_REFERENCE::value_type, FORWARD_REFERENCE::in_width> (*) [FORWARD_REFERENCE::n_chan], FORWARD_REFERENCE::value_type*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/nnet_utils/nnet_types.h:27) in function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator=(nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u> const&)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'void nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>(FORWARD_REFERENCE const&, ap_shift_reg<FORWARD_REFERENCE::value_type, FORWARD_REFERENCE::in_width> (*) [FORWARD_REFERENCE::n_chan], FORWARD_REFERENCE::value_type*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[]' into 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator=' (firmware/nnet_utils/nnet_types.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, config2>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config2_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::compute_output_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:203).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config4>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config4>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config4>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config4>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' into 'nnet::conv_2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 1u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator=' (firmware/nnet_utils/nnet_types.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce_pool<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16, config5>' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:204).
# INFO: [XFORM 203-603] Inlining function 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' into 'nnet::pooling2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:247).
# INFO: [XFORM 203-603] Inlining function 'nnet::pooling2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:188->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config5>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 3, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 3, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10_mult>' (firmware/nnet_utils/nnet_dense_resource.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 3, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config15>' (firmware/nnet_utils/nnet_dense_resource.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 3, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config18>' (firmware/nnet_utils/nnet_dense_resource.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:79->firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::compute_output_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:203).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' into 'nnet::conv_2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config10>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator=' (firmware/nnet_utils/nnet_types.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce_pool<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, config9>' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:204).
# INFO: [XFORM 203-603] Inlining function 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' into 'nnet::pooling2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:247).
# INFO: [XFORM 203-603] Inlining function 'nnet::pooling2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:188->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::Op_max<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()' into 'nnet::pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config9>' (firmware/nnet_utils/nnet_common.h:43->firmware/nnet_utils/nnet_common.h:45->firmware/nnet_utils/nnet_pooling_stream.h:21->firmware/nnet_utils/nnet_pooling_stream.h:204->firmware/nnet_utils/nnet_pooling_stream.h:247->firmware/nnet_utils/nnet_pooling_stream.h:257).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config10>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config10>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10_mult>' (firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10_mult>' into 'nnet::dense_resource<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, config10_mult>' (firmware/nnet_utils/nnet_dense_resource.h:79->firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>' (firmware/nnet_utils/nnet_pooling_stream.h:203).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config17>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config17>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config17>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config17>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config15>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config15>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::global_pooling2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config14>' (firmware/nnet_utils/nnet_pooling_stream.h:544).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config12>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config12>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config12>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, relu_config12>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' into 'nnet::conv_2d_cl<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config10>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[].1' into 'nnet::compute_global_pool<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config14>' (firmware/nnet_utils/nnet_pooling_stream.h:485).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[].1' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator[].1' into 'nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>::operator=' (firmware/nnet_utils/nnet_types.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>' into 'nnet::shift_line_buffer<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::reduce_pool<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, config13>' into 'nnet::compute_pool_buffer_2d<nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, nnet::array<ap_fixed<8, 0, (ap_q_mode)5, (ap_o_mode)3, 0>, 32u>, config13>' (firmware/nnet_utils/nnet_pooling_stream.h:204).
# ...
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 35 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:01:28 ; elapsed = 00:02:05 . Memory (MB): peak = 2234.141 ; gain = 847.816 ; free physical = 22472 ; free virtual = 33524
# Synthesis Optimization Complete : Time (s): cpu = 00:01:28 ; elapsed = 00:02:05 . Memory (MB): peak = 2234.141 ; gain = 847.816 ; free physical = 22484 ; free virtual = 33524
# INFO: [Project 1-571] Translating synthesized netlist
# INFO: [Netlist 29-17] Analyzing 3129 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_0 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_1 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_10 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_11 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_12 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_13 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_14 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_15 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_16 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_17 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_2 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_3 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_4 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_5 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_6 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_7 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_8 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s_fu_1015/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_fu_980/w10_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom_U/q0_reg_9 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s_fu_535/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_fu_516/w6_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom_U/q0_reg_0 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s_fu_535/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_fu_516/w6_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom_U/q0_reg_1 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s_fu_535/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_fu_516/w6_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom_U/q0_reg_2 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s_fu_535/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_fu_516/w6_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom_U/q0_reg_3 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s_fu_535/grp_dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_fu_516/w6_V_U/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom_U/q0_reg_4 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_0 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_1 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_2 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_3 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_4 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# INFO: [Opt 31-422] The CLOCK_DOMAINS attribute on the BRAM cell dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0/grp_dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_fu_1088/w15_V_U/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom_U/q0_reg_5 has been changed from INDEPENDENT to COMMON to match the clocking topology used for the BRAM.
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00.01 . Memory (MB): peak = 2313.941 ; gain = 0.000 ; free physical = 22396 ; free virtual = 33437
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 18 instances were transformed.
#   BUFG => BUFGCE: 1 instances
#   IBUF => IBUF (IBUFCTRL, INBUF): 17 instances
#
# INFO: [Common 17-83] Releasing license: Synthesis
# 911 Infos, 35 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:01:34 ; elapsed = 00:02:10 . Memory (MB): peak = 2313.941 ; gain = 927.617 ; free physical = 22525 ; free virtual = 33566
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Thu May 29 16:51:18 2025...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h2m18s *****
# INFO: [HLS 200-112] Total elapsed time: 265.83 seconds; peak allocated memory: 1.078 GB.
# INFO: [Common 17-206] Exiting vivado_hls at Thu May 29 16:51:19 2025...
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '4.375',
#   'BestLatency': '96751',
#   'WorstLatency': '96786',
#   'IntervalMin': '6914',
#   'IntervalMax': '96770',
#   'BRAM_18K': '119',
#   'DSP': '0',
#   'FF': '24060',
#   'LUT': '87219',
#   'URAM': '0',
#   'AvailableBRAM_18K': '1080',
#   'AvailableDSP': '1700',
#   'AvailableFF': '406256',
#   'AvailableLUT': '203128',
#   'AvailableURAM': '0'},
#  'VivadoSynthReport': {'LUT': '28951',
#   'FF': '22059',
#   'BRAM_18K': '30.5',
#   'DSP48E': '0'}}

# %%
hls4ml.report.read_vivado_report(hls_model.config.config['OutputDir'])
# Out:
# Found 1 solution(s) in rtl_models/model/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Thu May 29 16:48:52 2025
#
# * Version:        2019.1 (Build 2552052 on Fri May 24 15:28:33 MDT 2019)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: kintexu
# * Target device:  xcku035-fbva676-2-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing (ns):
#     * Summary:
#     +--------+-------+----------+------------+
#     |  Clock | Target| Estimated| Uncertainty|
#     +--------+-------+----------+------------+
#     |ap_clk  |   5.00|     4.375|        0.62|
#     +--------+-------+----------+------------+
#
# + Latency (clock cycles):
#     * Summary:
#     +-------+-------+------+-------+----------+
#     |    Latency    |   Interval   | Pipeline |
#     |  min  |  max  |  min |  max  |   Type   |
#     +-------+-------+------+-------+----------+
#     |  96751|  96786|  6914|  96770| dataflow |
#     +-------+-------+------+-------+----------+
#
#     + Detail:
#         * Instance:
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+------+-------+------+-------+----------+
#         |                                                                         |                                                                        |    Latency   |   Interval   | Pipeline |
#         |                                 Instance                                |                                 Module                                 |  min |  max  |  min |  max  |   Type   |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+------+-------+------+-------+----------+
#         |conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0   |conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_s   |    65|    689|    65|    689|   none   |
#         |pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_U0    |pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_s    |  2121|   2121|  2121|   2121|   none   |
#         |conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0     |conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_s     |   364|   5083|   364|   5083|   none   |
#         |pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_U0              |pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_s              |     7|      7|     7|      7|   none   |
#         |pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_U0  |pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_s  |    84|     84|    84|     84|   none   |
#         |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0        |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_s        |    34|     35|    34|     35|   none   |
#         |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_U0         |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_s         |    35|     36|    35|     36|   none   |
#         |conv_2d_cl_array_ap_fixed_1u_array_ap_fixed_8_0_5_3_0_8u_config2_U0      |conv_2d_cl_array_ap_fixed_1u_array_ap_fixed_8_0_5_3_0_8u_config2_s      |  6913|  96769|  6913|  96769|   none   |
#         |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_U0    |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_s    |     7|      7|     7|      7|   none   |
#         |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_U0    |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_s    |     1|      1|     1|      1| function |
#         |relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_U0     |relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_s     |    84|     84|    84|     84|   none   |
#         |relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_U0       |relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_s       |  2119|   2119|  2119|   2119|   none   |
#         |global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_U0       |global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_s       |     0|      0|     1|      1| function |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+------+-------+------+-------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+--------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |   LUT  | URAM|
# +-----------------+---------+-------+--------+--------+-----+
# |DSP              |        -|      -|       -|       -|    -|
# |Expression       |        -|      -|       0|       2|    -|
# |FIFO             |       72|      -|    3112|    7640|    -|
# |Instance         |       47|      0|   20948|   79577|    -|
# |Memory           |        -|      -|       -|       -|    -|
# |Multiplexer      |        -|      -|       -|       -|    -|
# |Register         |        -|      -|       -|       -|    -|
# +-----------------+---------+-------+--------+--------+-----+
# |Total            |      119|      0|   24060|   87219|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Available        |     1080|   1700|  406256|  203128|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Utilization (%)  |       11|      0|       5|      42|    0|
# +-----------------+---------+-------+--------+--------+-----+
#
# + Detail:
#     * Instance:
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+------+-------+-----+
#     |                                 Instance                                |                                 Module                                 | BRAM_18K| DSP48E|  FF  |  LUT  | URAM|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+------+-------+-----+
#     |conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_U0   |conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_s   |       29|      0|  7467|  33505|    0|
#     |conv_2d_cl_array_ap_fixed_1u_array_ap_fixed_8_0_5_3_0_8u_config2_U0      |conv_2d_cl_array_ap_fixed_1u_array_ap_fixed_8_0_5_3_0_8u_config2_s      |        0|      0|   712|   1749|    0|
#     |conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0     |conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_s     |        8|      0|  3940|  10435|    0|
#     |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0        |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_s        |        8|      0|  1814|   4354|    0|
#     |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_U0         |dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_s         |        2|      0|  1266|   2317|    0|
#     |global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_U0       |global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_s       |        0|      0|     3|    600|    0|
#     |pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_U0  |pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_s  |        0|      0|   981|   4045|    0|
#     |pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_U0    |pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_s    |        0|      0|  2228|  11389|    0|
#     |pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_U0              |pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_s              |        0|      0|  1777|   7575|    0|
#     |relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_U0     |relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_s     |        0|      0|   145|    700|    0|
#     |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_U0    |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_s    |        0|      0|   269|   1286|    0|
#     |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_U0    |relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_s    |        0|      0|   260|   1212|    0|
#     |relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_U0       |relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_s       |        0|      0|    86|    410|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+------+-------+-----+
#     |Total                                                                    |                                                                        |       47|      0| 20948|  79577|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+------+-------+-----+
#
# Co-simulation report not found.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  q_conv2d_batchnorm_5 (QConv  (None, 46, 46, 8)        113
#  2DBatchnorm)
#
#  q_activation_8 (QActivation  (None, 46, 46, 8)        0
#  )
#
#  max_pooling2d_5 (MaxPooling  (None, 11, 11, 8)        0
#  2D)
#
#  q_conv2d_batchnorm_6 (QConv  (None, 9, 9, 16)         1233
#  2DBatchnorm)
#
#  q_activation_9 (QActivation  (None, 9, 9, 16)         0
#  )
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  q_conv2d_batchnorm_7 (QConv  (None, 2, 2, 32)         4769
#  2DBatchnorm)
#
#  q_activation_10 (QActivatio  (None, 2, 2, 32)         0
#  n)
#
#  max_pooling2d_7 (MaxPooling  (None, 1, 1, 32)         0
#  2D)
#
#  global_average_pooling2d_1   (None, 32)               0
#  (GlobalAveragePooling2D)
#
#  q_dense_5 (QDense)          (None, 32)                1056
#
#  q_activation_11 (QActivatio  (None, 32)               0
#  n)
#
#  q_dense_6 (QDense)          (None, 5)                 165
#
# =================================================================
# Total params: 7,336
# Trainable params: 7,221
# Non-trainable params: 115
# _________________________________________________________________

# %%
hls_model.config.config['OutputDir']
# Out:
# 'rtl_models/model2'

# %%
for f in os.listdir(os.path.join(hls_model.config.config['OutputDir'].replace("2",""), "myproject_prj", "solution1", "syn", "verilog")):
    if not f.endswith(".dat"):
        print(f'vlog "./verilog/{f}"')
# Out:
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_1u_config2_s.v"
# vlog "./verilog/start_for_relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_U0.v"
# vlog "./verilog/fifo_w8_d81_A.v"
# vlog "./verilog/start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_U0.v"
# vlog "./verilog/dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_s.v"
# vlog "./verilog/relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_s.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s.v"
# vlog "./verilog/pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_s_line_bRg6.v"
# vlog "./verilog/start_for_relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_U0.v"
# vlog "./verilog/conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10_s.v"
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_8u_config6_s_line_buffer_Array_V_2Bew.v"
# vlog "./verilog/compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_8u_config2_s.v"
# vlog "./verilog/start_for_dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_5u_config18_U0.v"
# vlog "./verilog/fifo_w8_d16_A.v"
# vlog "./verilog/myproject_mux_83_8_1_1.v"
# vlog "./verilog/relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config17_s.v"
# vlog "./verilog/myproject_mux_42_8_1_1.v"
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_16u_config10_s_line_buffer_Array_V7jG.v"
# vlog "./verilog/start_for_pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_configb9t.v"
# vlog "./verilog/relu_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_relu_config8_s.v"
# vlog "./verilog/compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_32u_config10_s.v"
# vlog "./verilog/fifo_w8_d2116_A.v"
# vlog "./verilog/fifo_w8_d1_A.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config2_mult_s_w2_V.v"
# vlog "./verilog/myproject_mux_2568_8_1_1.v"
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_8u_config6_s.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config2_mult_s_outidx.v"
# vlog "./verilog/pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_s_line_buffer_Array_bDo.v"
# vlog "./verilog/myproject_mux_646_8_1_1.v"
# vlog "./verilog/fifo_w8_d4_A.v"
# vlog "./verilog/conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_s.v"
# vlog "./verilog/pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_s_line_bufdEe.v"
# vlog "./verilog/start_for_global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_U0.v"
# vlog "./verilog/start_for_relu_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_relu_config12_U0.v"
# vlog "./verilog/start_for_conv_2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_16u_config6_U0.v"
# vlog "./verilog/pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_s.v"
# vlog "./verilog/myproject_mux_325_8_1_1.v"
# vlog "./verilog/start_for_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_U0.v"
# vlog "./verilog/fifo_w8_d121_A.v"
# vlog "./verilog/start_for_pooling2d_cl_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_config5_U0.v"
# vlog "./verilog/pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config13_s.v"
# vlog "./verilog/start_for_dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_U0.v"
# vlog "./verilog/dense_array_ap_fixed_32u_array_ap_fixed_8_0_5_3_0_32u_config15_s.v"
# vlog "./verilog/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config18_s.v"
# vlog "./verilog/myproject_mux_164_8_1_1.v"
# vlog "./verilog/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s.v"
# vlog "./verilog/compute_output_buffer_2d_array_array_ap_fixed_8_0_5_3_0_16u_config6_s.v"
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_16u_config10_s.v"
# vlog "./verilog/global_pooling2d_cl_array_array_ap_fixed_8_0_5_3_0_32u_config14_s.v"
# vlog "./verilog/myproject.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config2_mult_s.v"
# vlog "./verilog/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config18_s_w18_V.v"
# vlog "./verilog/shift_line_buffer_array_ap_fixed_8_0_5_3_0_1u_config2_s_line_buffer_Array_V_1bkb.v"
# vlog "./verilog/conv_2d_cl_array_ap_fixed_1u_array_ap_fixed_8_0_5_3_0_8u_config2_s.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s.v"
# vlog "./verilog/relu_array_ap_fixed_8u_array_ap_fixed_8_0_5_3_0_8u_relu_config4_s.v"
# vlog "./verilog/pooling2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_16u_config9_s.v"
# vlog "./verilog/myproject_mux_1287_8_1_1.v"
# vlog "./verilog/dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V.v"
# vlog "./verilog/start_for_conv_2d_cl_array_ap_fixed_16u_array_ap_fixed_8_0_5_3_0_32u_config10cau.v"
# vlog "./verilog/dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V.v"

# %%
for f in os.listdir(os.path.join(hls_model.config.config['OutputDir'].replace("2",""), "myproject_prj", "solution1", "syn", "verilog")):
    if f.endswith(".dat"):
        print(f)
# Out:
# dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config2_mult_s_w2_V_rom.dat
# dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config15_s_w15_V_rom.dat
# dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config2_mult_s_outidx_rom.dat
# dense_wrapper_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config18_s_w18_V_rom.dat
# dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config10_mult_s_w10_V_rom.dat
# dense_resource_ap_fixed_8_0_5_3_0_ap_fixed_8_0_5_3_0_config6_mult_s_w6_V_rom.dat
